# %% [markdown]
# ## Import Libraries

# %%
import re
import boto3
import sagemaker
import numpy as np
from sagemaker import get_execution_role
from sklearn.model_selection import train_test_split


# Work with data
import io # The io module allows for dealing with various types of I/O (text I/O, binary I/O and raw I/O). 
import sagemaker.amazon.common as smac # sagemaker common libary

# %% [markdown]
# ## Variables configuration

# %%
bucket = sess.default_bucket()
prefix = "linear-learner"
output_location = f"s3://{bucket}/{prefix}/output"

RANDOM_SEED = 42
dataset = 'keypoint.csv'

# Define IAM role
role = get_execution_role()

sess = sagemaker.Session()
region = boto3.Session().region_name

# %% [markdown]
# ## Dataset

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1)))
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=(0))

X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)

# %% [markdown]
# ### Train

# %%
# Code below converts the data in numpy array format to RecordIO format
# This is the format required by Sagemaker Linear Learner 

buf = io.BytesIO() # create an in-memory byte array (buf is a buffer I will be writing to)
smac.write_numpy_to_dense_tensor(buf, X_train, y_train)
buf.seek(0) 
# When you write to in-memory byte arrays, it increments 1 every time you write to it
# Let's reset that back to zero
# Out:
# 0

# %%
import os

# Code to upload RecordIO data to S3
 
# Key refers to the name of the file    
key = 'linear-train-data'

# The following code uploads the data in record-io format to S3 bucket to be accessed later for training
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)

# Let's print out the training data location in s3
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
print('uploaded training data location: {}'.format(s3_train_data))
# Out:
# uploaded training data location: s3://sagemaker-us-east-1-410677554255/linear-learner/train/linear-train-data

# %% [markdown]
# ### Test

# %%
# Code to upload RecordIO data to S3

buf = io.BytesIO() # create an in-memory byte array (buf is a buffer I will be writing to)
smac.write_numpy_to_dense_tensor(buf, X_test, y_test)
buf.seek(0) 
# When you write to in-memory byte arrays, it increments 1 every time you write to it
# Let's reset that back to zero
# Out:
# 0

# %%
# Key refers to the name of the file    
key = 'linear-test-data'

# The following code uploads the data in record-io format to S3 bucket to be accessed later for training
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'test', key)).upload_fileobj(buf)

# Let's print out the testing data location in s3
s3_test_data = 's3://{}/{}/test/{}'.format(bucket, prefix, key)
print('uploaded training data location: {}'.format(s3_test_data))
# Out:
# uploaded training data location: s3://sagemaker-us-east-1-410677554255/linear-learner/test/linear-test-data

# %%
# create an output placeholder in S3 bucket to store the linear learner output

output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('Training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# Training artifacts will be uploaded to: s3://sagemaker-us-east-1-410677554255/linear-learner/output

# %%
from sagemaker import image_uris
container = image_uris.retrieve(region=boto3.Session().region_name, framework="linear-learner")

# %%
# We have pass in the container, the type of instance that we would like to use for training 
# output path and sagemaker session into the Estimator. 
# We can also specify how many instances we would like to use for training
# sagemaker_session = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       instance_count = 1, 
                                       instance_type = 'ml.c4.xlarge',
                                       output_path = output_location,
                                       sagemaker_session = sess)


# We can tune parameters like the number of features that we are passing in, type of predictor like 'regressor' or 'classifier', mini batch size, epochs
# Train 8 different versions of the model and will get the best out of them (built-in parameters optimization!)

linear.set_hyperparameters(feature_dim = 42,
                           predictor_type = 'multiclass_classifier',
                           mini_batch_size = 60,
                           epochs = 5,
                           num_classes = 4,
                           num_models = 8,
                           loss = 'softmax_loss')
# Now we are ready to pass in the training data from S3 to train the linear learner model

linear.fit({'train': s3_train_data})

# Let's see the progress using cloudwatch logs
# Out:
# 2022-11-10 15:56:58 Starting - Starting the training job...
# 2022-11-10 15:57:21 Starting - Preparing the instances for trainingProfilerReport-1668095818: InProgress
# .........
# 2022-11-10 15:58:55 Downloading - Downloading input data
# 2022-11-10 15:58:55 Training - Downloading the training image.........
# 2022-11-10 16:00:26 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [11/10/2022 16:00:30 INFO 140133525714752] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [11/10/2022 16:00:30 INFO 140133525714752] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'epochs': '5', 'feature_dim': '42', 'loss': 'softmax_loss', 'mini_batch_size': '60', 'num_classes': '4', 'num_models': '8', 'predictor_type': 'multiclass_classifier'}
# [11/10/2022 16:00:30 INFO 140133525714752] Final configuration: {'mini_batch_size': '60', 'epochs': '5', 'feature_dim': '42', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '8', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'softmax_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '4', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'multiclass_classifier'}
# [11/10/2022 16:00:35 WARNING 140133525714752] Loggers have already been setup.
# [11/10/2022 16:00:35 INFO 140133525714752] Final configuration: {'mini_batch_size': '60', 'epochs': '5', 'feature_dim': '42', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '8', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'softmax_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '4', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'multiclass_classifier'}
# [11/10/2022 16:00:35 WARNING 140133525714752] Loggers have already been setup.
# Process 1 is a worker.
# [11/10/2022 16:00:35 INFO 140133525714752] Using default worker.
# [11/10/2022 16:00:35 INFO 140133525714752] Checkpoint loading and saving are disabled.
# [2022-11-10 16:00:35.494] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 14, "num_examples": 1, "num_bytes": 12960}
# [11/10/2022 16:00:35 INFO 140133525714752] Create Store: local
# [2022-11-10 16:00:35.756] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 260, "num_examples": 60, "num_bytes": 775440}
# [11/10/2022 16:00:35 INFO 140133525714752] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f72d7280210>
# [11/10/2022 16:00:35 INFO 140133525714752] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [1.         1.         0.22754605 0.16228096 0.41835755 0.3008688
#  0.5376531  0.41630164 0.5943243  0.4959579  0.46589327 0.35077012
#  0.5855362  0.45014435 0.6194775  0.4911592  0.66259754 0.5400306
#  0.39328125 0.32731083 0.49478084 0.42061594 0.48854646 0.45303705
#  0.510916   0.49364662 0.33975735 0.3052846  0.4228218  0.39451364
#  0.4127581  0.4239757  0.4303126  0.46445975 0.32338405 0.29787266
#  0.3825911  0.3705544  0.3691771  0.38384128 0.37704757 0.4121495 ]
# <NDArray 42 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 0.          0.         -0.05111935 -0.06241107 -0.07756161 -0.15516238
#  -0.06731927 -0.23312423 -0.0393685  -0.3001813  -0.03969235 -0.38917458
#  -0.03539905 -0.47320715 -0.03770901 -0.44935298 -0.03609356 -0.43817294
#   0.01132336 -0.40752196  0.01774503 -0.45063934  0.00095257 -0.3847838
#  -0.0117111  -0.37534028  0.05403338 -0.37798193  0.0607034  -0.3991061
#   0.0375284  -0.3403082   0.02198217 -0.34059668  0.08609489 -0.32375178
#   0.08801556 -0.33842358  0.06455461 -0.29773733  0.0463688  -0.29780716]
# <NDArray 42 @cpu(0)>}
# [11/10/2022 16:00:35 INFO 140133525714752] nvidia-smi: took 0.032 seconds to run.
# [11/10/2022 16:00:35 INFO 140133525714752] nvidia-smi identified 0 GPUs.
# [11/10/2022 16:00:35 INFO 140133525714752] Number of GPUs being used: 0
# #metrics {"StartTime": 1668096035.833978, "EndTime": 1668096035.8340144, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3650.0, "count": 1, "min": 3650, "max": 3650}, "Total Batches Seen": {"sum": 61.0, "count": 1, "min": 61, "max": 61}, "Max Records Seen Between Resets": {"sum": 3590.0, "count": 1, "min": 3590, "max": 3590}, "Max Batches Seen Between Resets": {"sum": 60.0, "count": 1, "min": 60, "max": 60}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2022-11-10 16:00:36.422] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 588, "num_examples": 60, "num_bytes": 775440}
# #metrics {"StartTime": 1668096036.42252, "EndTime": 1668096036.4225826, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8283809349361786, "count": 1, "min": 0.8283809349361786, "max": 0.8283809349361786}}}
# #metrics {"StartTime": 1668096036.4226944, "EndTime": 1668096036.4227116, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8566498147565766, "count": 1, "min": 0.8566498147565766, "max": 0.8566498147565766}}}
# #metrics {"StartTime": 1668096036.4227555, "EndTime": 1668096036.4227664, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8207535619789598, "count": 1, "min": 0.8207535619789598, "max": 0.8207535619789598}}}
# #metrics {"StartTime": 1668096036.4228072, "EndTime": 1668096036.42282, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8189055415870106, "count": 1, "min": 0.8189055415870106, "max": 0.8189055415870106}}}
# #metrics {"StartTime": 1668096036.422862, "EndTime": 1668096036.4228728, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9342147148261636, "count": 1, "min": 0.9342147148261636, "max": 0.9342147148261636}}}
# #metrics {"StartTime": 1668096036.42291, "EndTime": 1668096036.4229198, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9605404697569077, "count": 1, "min": 0.9605404697569077, "max": 0.9605404697569077}}}
# #metrics {"StartTime": 1668096036.4229527, "EndTime": 1668096036.4229622, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9313249415596999, "count": 1, "min": 0.9313249415596999, "max": 0.9313249415596999}}}
# #metrics {"StartTime": 1668096036.4229946, "EndTime": 1668096036.4230042, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0431237366239903, "count": 1, "min": 1.0431237366239903, "max": 1.0431237366239903}}}
# [11/10/2022 16:00:36 INFO 140133525714752] #quality_metric: host=algo-1, epoch=0, train multiclass_cross_entropy_objective <loss>=0.8283809349361786
# [11/10/2022 16:00:36 INFO 140133525714752] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=multiclass_cross_entropy_objective, value=0.8189055415870106
# [11/10/2022 16:00:36 INFO 140133525714752] Epoch 0: Loss improved. Updating best model
# [11/10/2022 16:00:36 INFO 140133525714752] Saving model for epoch: 0
# [11/10/2022 16:00:36 INFO 140133525714752] Saved checkpoint to "/tmp/tmppgy9623y/mx-mod-0000.params"
# [11/10/2022 16:00:36 INFO 140133525714752] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1668096035.8343058, "EndTime": 1668096036.4345918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 7240.0, "count": 1, "min": 7240, "max": 7240}, "Total Batches Seen": {"sum": 121.0, "count": 1, "min": 121, "max": 121}, "Max Records Seen Between Resets": {"sum": 3590.0, "count": 1, "min": 3590, "max": 3590}, "Max Batches Seen Between Resets": {"sum": 60.0, "count": 1, "min": 60, "max": 60}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 3590.0, "count": 1, "min": 3590, "max": 3590}, "Number of Batches Since Last Reset": {"sum": 60.0, "count": 1, "min": 60, "max": 60}}}
# [11/10/2022 16:00:36 INFO 140133525714752] #throughput_metric: host=algo-1, train throughput=5979.024490191376 records/second
# [2022-11-10 16:00:37.017] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 582, "num_examples": 60, "num_bytes": 775440}
# #metrics {"StartTime": 1668096037.0175633, "EndTime": 1668096037.0176146, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6618256746712378, "count": 1, "min": 0.6618256746712378, "max": 0.6618256746712378}}}
# #metrics {"StartTime": 1668096037.0177035, "EndTime": 1668096037.0177183, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6784662683131331, "count": 1, "min": 0.6784662683131331, "max": 0.6784662683131331}}}
# #metrics {"StartTime": 1668096037.0177574, "EndTime": 1668096037.0177677, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6519726543103235, "count": 1, "min": 0.6519726543103235, "max": 0.6519726543103235}}}
# #metrics {"StartTime": 1668096037.0178037, "EndTime": 1668096037.0178173, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6520714161759716, "count": 1, "min": 0.6520714161759716, "max": 0.6520714161759716}}}
# #metrics {"StartTime": 1668096037.017856, "EndTime": 1668096037.0178661, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8621811301021253, "count": 1, "min": 0.8621811301021253, "max": 0.8621811301021253}}}
# #metrics {"StartTime": 1668096037.0179021, "EndTime": 1668096037.017912, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8124745643745035, "count": 1, "min": 0.8124745643745035, "max": 0.8124745643745035}}}
# #metrics {"StartTime": 1668096037.0179493, "EndTime": 1668096037.0179605, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8851528307812362, "count": 1, "min": 0.8851528307812362, "max": 0.8851528307812362}}}
# #metrics {"StartTime": 1668096037.017995, "EndTime": 1668096037.0180047, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9727432703567763, "count": 1, "min": 0.9727432703567763, "max": 0.9727432703567763}}}
# [11/10/2022 16:00:37 INFO 140133525714752] #quality_metric: host=algo-1, epoch=1, train multiclass_cross_entropy_objective <loss>=0.6618256746712378
# [11/10/2022 16:00:37 INFO 140133525714752] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=multiclass_cross_entropy_objective, value=0.6519726543103235
# [11/10/2022 16:00:37 INFO 140133525714752] Epoch 1: Loss improved. Updating best model
# [11/10/2022 16:00:37 INFO 140133525714752] Saving model for epoch: 1
# [11/10/2022 16:00:37 INFO 140133525714752] Saved checkpoint to "/tmp/tmpc3iz1kuy/mx-mod-0000.params"
# [11/10/2022 16:00:37 INFO 140133525714752] #progress_metric: host=algo-1, completed 40.0 % of epochs
# #metrics {"StartTime": 1668096036.4349153, "EndTime": 1668096037.0270553, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 10830.0, "count": 1, "min": 10830, "max": 10830}, "Total Batches Seen": {"sum": 181.0, "count": 1, "min": 181, "max": 181}, "Max Records Seen Between Resets": {"sum": 3590.0, "count": 1, "min": 3590, "max": 3590}, "Max Batches Seen Between Resets": {"sum": 60.0, "count": 1, "min": 60, "max": 60}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 3590.0, "count": 1, "min": 3590, "max": 3590}, "Number of Batches Since Last Reset": {"sum": 60.0, "count": 1, "min": 60, "max": 60}}}
# [11/10/2022 16:00:37 INFO 140133525714752] #throughput_metric: host=algo-1, train throughput=6061.525780367205 records/second
# [2022-11-10 16:00:37.687] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 660, "num_examples": 60, "num_bytes": 775440}
# #metrics {"StartTime": 1668096037.6881733, "EndTime": 1668096037.6882348, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6441810392390537, "count": 1, "min": 0.6441810392390537, "max": 0.6441810392390537}}}
# #metrics {"StartTime": 1668096037.688376, "EndTime": 1668096037.6883926, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6416431604805639, "count": 1, "min": 0.6416431604805639, "max": 0.6416431604805639}}}
# #metrics {"StartTime": 1668096037.6884468, "EndTime": 1668096037.6884577, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6400248004891778, "count": 1, "min": 0.6400248004891778, "max": 0.6400248004891778}}}
# #metrics {"StartTime": 1668096037.688487, "EndTime": 1668096037.6885004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6213101516335697, "count": 1, "min": 0.6213101516335697, "max": 0.6213101516335697}}}
# #metrics {"StartTime": 1668096037.6885483, "EndTime": 1668096037.688563, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8516602941825565, "count": 1, "min": 0.8516602941825565, "max": 0.8516602941825565}}}
# #metrics {"StartTime": 1668096037.6886108, "EndTime": 1668096037.6886265, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.7996465101080426, "count": 1, "min": 0.7996465101080426, "max": 0.7996465101080426}}}
# #metrics {"StartTime": 1668096037.6886764, "EndTime": 1668096037.6886916, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8796977458027123, "count": 1, "min": 0.8796977458027123, "max": 0.8796977458027123}}}
# #metrics {"StartTime": 1668096037.688741, "EndTime": 1668096037.6887562, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9657317813506908, "count": 1, "min": 0.9657317813506908, "max": 0.9657317813506908}}}
# [11/10/2022 16:00:37 INFO 140133525714752] #quality_metric: host=algo-1, epoch=2, train multiclass_cross_entropy_objective <loss>=0.6441810392390537
# [11/10/2022 16:00:37 INFO 140133525714752] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=multiclass_cross_entropy_objective, value=0.6213101516335697
# [11/10/2022 16:00:37 INFO 140133525714752] Epoch 2: Loss improved. Updating best model
# [11/10/2022 16:00:37 INFO 140133525714752] Saving model for epoch: 2
# [11/10/2022 16:00:37 INFO 140133525714752] Saved checkpoint to "/tmp/tmp761zfjln/mx-mod-0000.params"
# [11/10/2022 16:00:37 INFO 140133525714752] #progress_metric: host=algo-1, completed 60.0 % of epochs
# #metrics {"StartTime": 1668096037.0273225, "EndTime": 1668096037.6990085, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 14420.0, "count": 1, "min": 14420, "max": 14420}, "Total Batches Seen": {"sum": 241.0, "count": 1, "min": 241, "max": 241}, "Max Records Seen Between Resets": {"sum": 3590.0, "count": 1, "min": 3590, "max": 3590}, "Max Batches Seen Between Resets": {"sum": 60.0, "count": 1, "min": 60, "max": 60}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 3590.0, "count": 1, "min": 3590, "max": 3590}, "Number of Batches Since Last Reset": {"sum": 60.0, "count": 1, "min": 60, "max": 60}}}
# [11/10/2022 16:00:37 INFO 140133525714752] #throughput_metric: host=algo-1, train throughput=5343.5402416978895 records/second
# [2022-11-10 16:00:38.342] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 642, "num_examples": 60, "num_bytes": 775440}
# #metrics {"StartTime": 1668096038.3421965, "EndTime": 1668096038.342254, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6361903734799832, "count": 1, "min": 0.6361903734799832, "max": 0.6361903734799832}}}
# #metrics {"StartTime": 1668096038.342346, "EndTime": 1668096038.342365, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6263258621517548, "count": 1, "min": 0.6263258621517548, "max": 0.6263258621517548}}}
# #metrics {"StartTime": 1668096038.342418, "EndTime": 1668096038.3424354, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6321696766352249, "count": 1, "min": 0.6321696766352249, "max": 0.6321696766352249}}}
# #metrics {"StartTime": 1668096038.3424892, "EndTime": 1668096038.342506, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6078416759684935, "count": 1, "min": 0.6078416759684935, "max": 0.6078416759684935}}}
# #metrics {"StartTime": 1668096038.3425639, "EndTime": 1668096038.3425808, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8442026666328732, "count": 1, "min": 0.8442026666328732, "max": 0.8442026666328732}}}
# #metrics {"StartTime": 1668096038.3426316, "EndTime": 1668096038.3426478, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.7940130740235755, "count": 1, "min": 0.7940130740235755, "max": 0.7940130740235755}}}
# #metrics {"StartTime": 1668096038.3427267, "EndTime": 1668096038.3427446, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8762557045888093, "count": 1, "min": 0.8762557045888093, "max": 0.8762557045888093}}}
# #metrics {"StartTime": 1668096038.3427942, "EndTime": 1668096038.3428106, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9642769851253531, "count": 1, "min": 0.9642769851253531, "max": 0.9642769851253531}}}
# [11/10/2022 16:00:38 INFO 140133525714752] #quality_metric: host=algo-1, epoch=3, train multiclass_cross_entropy_objective <loss>=0.6361903734799832
# [11/10/2022 16:00:38 INFO 140133525714752] #early_stopping_criteria_metric: host=algo-1, epoch=3, criteria=multiclass_cross_entropy_objective, value=0.6078416759684935
# [11/10/2022 16:00:38 INFO 140133525714752] Epoch 3: Loss improved. Updating best model
# [11/10/2022 16:00:38 INFO 140133525714752] Saving model for epoch: 3
# [11/10/2022 16:00:38 INFO 140133525714752] Saved checkpoint to "/tmp/tmpfa12liof/mx-mod-0000.params"
# [11/10/2022 16:00:38 INFO 140133525714752] #progress_metric: host=algo-1, completed 80.0 % of epochs
# #metrics {"StartTime": 1668096037.6993241, "EndTime": 1668096038.3544147, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 18010.0, "count": 1, "min": 18010, "max": 18010}, "Total Batches Seen": {"sum": 301.0, "count": 1, "min": 301, "max": 301}, "Max Records Seen Between Resets": {"sum": 3590.0, "count": 1, "min": 3590, "max": 3590}, "Max Batches Seen Between Resets": {"sum": 60.0, "count": 1, "min": 60, "max": 60}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 3590.0, "count": 1, "min": 3590, "max": 3590}, "Number of Batches Since Last Reset": {"sum": 60.0, "count": 1, "min": 60, "max": 60}}}
# [11/10/2022 16:00:38 INFO 140133525714752] #throughput_metric: host=algo-1, train throughput=5478.913979797495 records/second
# [2022-11-10 16:00:38.988] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 12, "duration": 633, "num_examples": 60, "num_bytes": 775440}
# #metrics {"StartTime": 1668096038.988611, "EndTime": 1668096038.9886692, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6298506887619105, "count": 1, "min": 0.6298506887619105, "max": 0.6298506887619105}}}
# #metrics {"StartTime": 1668096038.9887657, "EndTime": 1668096038.9887834, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6182127176705053, "count": 1, "min": 0.6182127176705053, "max": 0.6182127176705053}}}
# #metrics {"StartTime": 1668096038.9888306, "EndTime": 1668096038.9888444, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6269085501546914, "count": 1, "min": 0.6269085501546914, "max": 0.6269085501546914}}}
# #metrics {"StartTime": 1668096038.9888875, "EndTime": 1668096038.9889007, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5999520581994353, "count": 1, "min": 0.5999520581994353, "max": 0.5999520581994353}}}
# #metrics {"StartTime": 1668096038.9889414, "EndTime": 1668096038.9889534, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8382198624691721, "count": 1, "min": 0.8382198624691721, "max": 0.8382198624691721}}}
# #metrics {"StartTime": 1668096038.9889913, "EndTime": 1668096038.9890025, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.7913944793959795, "count": 1, "min": 0.7913944793959795, "max": 0.7913944793959795}}}
# #metrics {"StartTime": 1668096038.9890397, "EndTime": 1668096038.9890509, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8737340485308803, "count": 1, "min": 0.8737340485308803, "max": 0.8737340485308803}}}
# #metrics {"StartTime": 1668096038.9890878, "EndTime": 1668096038.9890988, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9638944798270188, "count": 1, "min": 0.9638944798270188, "max": 0.9638944798270188}}}
# [11/10/2022 16:00:38 INFO 140133525714752] #quality_metric: host=algo-1, epoch=4, train multiclass_cross_entropy_objective <loss>=0.6298506887619105
# [11/10/2022 16:00:38 INFO 140133525714752] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=multiclass_cross_entropy_objective, value=0.5999520581994353
# [11/10/2022 16:00:38 INFO 140133525714752] Epoch 4: Loss improved. Updating best model
# [11/10/2022 16:00:38 INFO 140133525714752] Saving model for epoch: 4
# [11/10/2022 16:00:38 INFO 140133525714752] Saved checkpoint to "/tmp/tmp5_skfksx/mx-mod-0000.params"
# [11/10/2022 16:00:38 INFO 140133525714752] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1668096038.354741, "EndTime": 1668096038.9996295, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 21600.0, "count": 1, "min": 21600, "max": 21600}, "Total Batches Seen": {"sum": 361.0, "count": 1, "min": 361, "max": 361}, "Max Records Seen Between Resets": {"sum": 3590.0, "count": 1, "min": 3590, "max": 3590}, "Max Batches Seen Between Resets": {"sum": 60.0, "count": 1, "min": 60, "max": 60}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 3590.0, "count": 1, "min": 3590, "max": 3590}, "Number of Batches Since Last Reset": {"sum": 60.0, "count": 1, "min": 60, "max": 60}}}
# [11/10/2022 16:00:38 INFO 140133525714752] #throughput_metric: host=algo-1, train throughput=5565.692078466103 records/second
# [11/10/2022 16:00:39 WARNING 140133525714752] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/10/2022 16:00:39 WARNING 140133525714752] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2022-11-10 16:00:39.001] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 14, "duration": 0, "num_examples": 1, "num_bytes": 12960}
# [2022-11-10 16:00:39.404] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 16, "duration": 398, "num_examples": 60, "num_bytes": 775440}
# /opt/amazon/lib/python3.7/site-packages/numpy/core/fromnumeric.py:87: VisibleDeprecationWarning: Creating an ndarray from nested sequences exceeding the maximum number of dimensions of 32 is deprecated. If you mean to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# [11/10/2022 16:00:39 INFO 140133525714752] #train_score (algo-1) : ('multiclass_cross_entropy_objective', 0.5704008931237011)
# [11/10/2022 16:00:39 INFO 140133525714752] #train_score (algo-1) : ('multiclass_accuracy', 0.8192200557103064)
# [11/10/2022 16:00:39 INFO 140133525714752] #train_score (algo-1) : ('multiclass_top_k_accuracy_3', 0.9986072423398329)
# [11/10/2022 16:00:39 INFO 140133525714752] #train_score (algo-1) : ('dcg', 0.9223511581633417)
# [11/10/2022 16:00:39 INFO 140133525714752] #train_score (algo-1) : ('macro_recall', 0.85341346)
# [11/10/2022 16:00:39 INFO 140133525714752] #train_score (algo-1) : ('macro_precision', 0.84730124)
# [11/10/2022 16:00:39 INFO 140133525714752] #train_score (algo-1) : ('macro_f_1.000', 0.84854615)
# [11/10/2022 16:00:39 INFO 140133525714752] #train_score (algo-1) : ('multiclass_balanced_accuracy', 0.8534134191719445)
# [11/10/2022 16:00:39 INFO 140133525714752] #train_score (algo-1) : ('multiclass_log_loss', 0.9870731411591489)
# [11/10/2022 16:00:39 INFO 140133525714752] #quality_metric: host=algo-1, train multiclass_cross_entropy_objective <loss>=0.5704008931237011
# [11/10/2022 16:00:39 INFO 140133525714752] #quality_metric: host=algo-1, train multiclass_accuracy <score>=0.8192200557103064
# [11/10/2022 16:00:39 INFO 140133525714752] #quality_metric: host=algo-1, train multiclass_top_k_accuracy_3 <score>=0.9986072423398329
# [11/10/2022 16:00:39 INFO 140133525714752] #quality_metric: host=algo-1, train dcg <score>=0.9223511581633417
# [11/10/2022 16:00:39 INFO 140133525714752] #quality_metric: host=algo-1, train macro_recall <score>=0.853413462638855
# [11/10/2022 16:00:39 INFO 140133525714752] #quality_metric: host=algo-1, train macro_precision <score>=0.8473012447357178
# [11/10/2022 16:00:39 INFO 140133525714752] #quality_metric: host=algo-1, train macro_f_1.000 <score>=0.8485461473464966
# [11/10/2022 16:00:39 INFO 140133525714752] #quality_metric: host=algo-1, train multiclass_balanced_accuracy <score>=0.8534134191719445
# [11/10/2022 16:00:39 INFO 140133525714752] #quality_metric: host=algo-1, train multiclass_log_loss <score>=0.9870731411591489
# [11/10/2022 16:00:39 INFO 140133525714752] Best model found for hyperparameters: {"optimizer": "rmsprop", "learning_rate": 0.030664730174005284, "l1": 0.009948047153559398, "wd": 0.0011287804605356671, "lr_scheduler_step": 364, "lr_scheduler_factor": 0.9906266924715834, "lr_scheduler_minimum_lr": 0.0006780227021579834}
# [11/10/2022 16:00:39 INFO 140133525714752] Saved checkpoint to "/tmp/tmp9znv0dyl/mx-mod-0000.params"
# [11/10/2022 16:00:39 INFO 140133525714752] Test data is not provided.
# #metrics {"StartTime": 1668096035.47964, "EndTime": 1668096039.430701, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 352.92983055114746, "count": 1, "min": 352.92983055114746, "max": 352.92983055114746}, "epochs": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "check_early_stopping.time": {"sum": 5.393266677856445, "count": 5, "min": 0.8556842803955078, "max": 1.2898445129394531}, "update.time": {"sum": 3144.2856788635254, "count": 5, "min": 589.2505645751953, "max": 667.4668788909912}, "finalize.time": {"sum": 425.539493560791, "count": 1, "min": 425.539493560791, "max": 425.539493560791}, "setuptime": {"sum": 7.676601409912109, "count": 1, "min": 7.676601409912109, "max": 7.676601409912109}, "totaltime": {"sum": 4193.678617477417, "count": 1, "min": 4193.678617477417, "max": 4193.678617477417}}}
#
# 2022-11-10 16:00:46 Uploading - Uploading generated training model
# 2022-11-10 16:01:22 Completed - Training job completed
# ProfilerReport-1668095818: NoIssuesFound
# Training seconds: 153
# Billable seconds: 153

# %%
linear_regressor = linear.deploy(initial_instance_count = 1,
                                          instance_type = 'ml.m4.xlarge')
# Out:
# --------!

# %%
from sagemaker.predictor import csv_serializer, json_deserializer

linear_regressor.content_types = 'text/csv'
linear_regressor.serializer = csv_serializer
linear_regressor.deserializer = json_deserializer

# %%
result['predictions']
# Out:
# [{'score': [0.6482167840003967,
#    0.11138279736042023,
#    0.24028529226779938,
#    0.00011509278556331992],
#   'predicted_label': 0},
#  {'score': [0.972072422504425,
#    0.018346454948186874,
#    0.00956850778311491,
#    1.2633706319320481e-05],
#   'predicted_label': 0},
#  {'score': [0.28350716829299927,
#    0.09271127730607986,
#    0.6237677931785583,
#    1.3740491340286098e-05],
#   'predicted_label': 2},
#  {'score': [0.8245282173156738,
#    0.034943751990795135,
#    0.1405210644006729,
#    6.981278147577541e-06],
#   'predicted_label': 0},
#  {'score': [0.0010490157874301076,
#    0.9824925065040588,
#    0.01122354157269001,
#    0.005234922282397747],
#   'predicted_label': 1},
#  {'score': [0.009816275909543037,
#    0.03653404489159584,
#    0.0007362017058767378,
#    0.9529134631156921],
#   'predicted_label': 3},
#  {'score': [0.07809475064277649,
#    0.7898159623146057,
#    0.13208530843257904,
#    3.954525254812324e-06],
#   'predicted_label': 1},
#  {'score': [0.09362044930458069,
#    0.043714623898267746,
#    0.8626648783683777,
#    1.0611225320644735e-07],
#   'predicted_label': 2},
#  {'score': [0.8893210887908936,
#    0.050078392028808594,
#    0.05319961905479431,
#    0.00740089500322938],
#   'predicted_label': 0},
#  {'score': [0.929054856300354,
#    0.01628417707979679,
#    0.050310615450143814,
#    0.004350337199866772],
#   'predicted_label': 0},
#  {'score': [0.19117560982704163,
#    0.21982280910015106,
#    0.5890015959739685,
#    3.997672948230502e-08],
#   'predicted_label': 2},
#  {'score': [0.16211077570915222,
#    0.06324069201946259,
#    0.7746480107307434,
#    5.194142431719229e-07],
#   'predicted_label': 2},
#  {'score': [0.007851960137486458,
#    0.9148120880126953,
#    0.07696117460727692,
#    0.00037476595025509596],
#   'predicted_label': 1},
#  {'score': [0.0031334110535681248,
#    0.9686506390571594,
#    0.024578940123319626,
#    0.0036369841545820236],
#   'predicted_label': 1},
#  {'score': [0.002313276519998908,
#    0.9829592108726501,
#    0.014319146983325481,
#    0.0004083779058419168],
#   'predicted_label': 1},
#  {'score': [0.3240533173084259,
#    0.5709953308105469,
#    0.10387398302555084,
#    0.0010772678069770336],
#   'predicted_label': 1},
#  {'score': [0.12313994765281677,
#    0.7981938123703003,
#    0.07644219696521759,
#    0.0022240898106247187],
#   'predicted_label': 1},
#  {'score': [0.43074798583984375,
#    0.20193469524383545,
#    0.3673163056373596,
#    1.015462430586922e-06],
#   'predicted_label': 0},
#  {'score': [0.9318090677261353,
#    0.024748288094997406,
#    0.04343314468860626,
#    9.515688361716457e-06],
#   'predicted_label': 0},
#  {'score': [0.49695155024528503,
#    0.20138855278491974,
#    0.08300982415676117,
#    0.21865004301071167],
#   'predicted_label': 0},
#  {'score': [0.07430606335401535,
#    0.13310296833515167,
#    0.7925797700881958,
#    1.1147852092108224e-05],
#   'predicted_label': 2},
#  {'score': [0.22945697605609894,
#    0.11798802018165588,
#    0.6525521874427795,
#    2.829859795383527e-06],
#   'predicted_label': 2},
#  {'score': [0.28154534101486206,
#    0.0820997953414917,
#    0.6363428235054016,
#    1.2091214557585772e-05],
#   'predicted_label': 2},
#  {'score': [0.050266675651073456,
#    0.8501542210578918,
#    0.04591789469122887,
#    0.053661271929740906],
#   'predicted_label': 1},
#  {'score': [0.3988082706928253,
#    0.007243244908750057,
#    0.5939483046531677,
#    1.1594706705864155e-07],
#   'predicted_label': 2},
#  {'score': [0.3779604434967041,
#    0.15912963449954987,
#    0.4629093110561371,
#    6.010811830492457e-07],
#   'predicted_label': 2},
#  {'score': [0.5992331504821777,
#    0.33504927158355713,
#    0.06571508198976517,
#    2.5433971586608095e-06],
#   'predicted_label': 0},
#  {'score': [0.0013041157508268952,
#    0.05030425637960434,
#    0.0009486667113378644,
#    0.9474429488182068],
#   'predicted_label': 3},
#  {'score': [0.20215578377246857,
#    0.006406353786587715,
#    0.7914379239082336,
#    2.8295104925746273e-08],
#   'predicted_label': 2},
#  {'score': [0.9185190796852112,
#    0.03883989527821541,
#    0.03879709914326668,
#    0.0038439398631453514],
#   'predicted_label': 0},
#  {'score': [0.38076135516166687,
#    0.10068266838788986,
#    0.5185490250587463,
#    6.971556103962939e-06],
#   'predicted_label': 2},
#  {'score': [0.5244055390357971,
#    0.09521670639514923,
#    0.15208041667938232,
#    0.22829735279083252],
#   'predicted_label': 0},
#  {'score': [0.000514771556481719,
#    0.9918003082275391,
#    0.004575564060360193,
#    0.0031094257719814777],
#   'predicted_label': 1},
#  {'score': [0.0003263118851464242,
#    0.98797607421875,
#    0.004621576983481646,
#    0.007076028268784285],
#   'predicted_label': 1},
#  {'score': [0.24372579157352448,
#    0.32325395941734314,
#    0.4330122768878937,
#    8.016110768949147e-06],
#   'predicted_label': 2},
#  {'score': [0.9296247363090515,
#    0.03165052458643913,
#    0.03714887052774429,
#    0.001575902453623712],
#   'predicted_label': 0},
#  {'score': [0.4813591241836548,
#    0.2614574730396271,
#    0.1031312420964241,
#    0.15405216813087463],
#   'predicted_label': 0},
#  {'score': [0.0032656395342200994,
#    0.9921911954879761,
#    0.00424943957477808,
#    0.00029376382008194923],
#   'predicted_label': 1},
#  {'score': [0.5395726561546326,
#    0.020740089938044548,
#    0.43968725204467773,
#    1.000000013351432e-10],
#   'predicted_label': 0},
#  {'score': [0.9383836984634399,
#    0.02444242686033249,
#    0.029896806925535202,
#    0.007277017459273338],
#   'predicted_label': 0},
#  {'score': [0.8705581426620483,
#    0.055526964366436005,
#    0.0724918469786644,
#    0.0014230641536414623],
#   'predicted_label': 0},
#  {'score': [0.9310646057128906,
#    0.013721506111323833,
#    0.04913508519530296,
#    0.006078751292079687],
#   'predicted_label': 0},
#  {'score': [0.01105411909520626,
#    0.9578949213027954,
#    0.029896501451730728,
#    0.0011544680455699563],
#   'predicted_label': 1},
#  {'score': [0.0064227827824652195,
#    0.02636735700070858,
#    0.0008322385256178677,
#    0.9663776755332947],
#   'predicted_label': 3},
#  {'score': [0.4492746889591217,
#    0.24217768013477325,
#    0.30847203731536865,
#    7.560682570328936e-05],
#   'predicted_label': 0},
#  {'score': [0.020476896315813065,
#    0.06662672758102417,
#    0.9128954410552979,
#    9.096771123040526e-07],
#   'predicted_label': 2},
#  {'score': [0.3557474613189697,
#    0.37421002984046936,
#    0.2700332999229431,
#    9.182032954413444e-06],
#   'predicted_label': 1},
#  {'score': [0.3661680221557617,
#    0.25951510667800903,
#    0.07956713438034058,
#    0.29474973678588867],
#   'predicted_label': 0},
#  {'score': [0.0008384251850657165,
#    0.9930662512779236,
#    0.004111278336495161,
#    0.001984143629670143],
#   'predicted_label': 1},
#  {'score': [0.10816269367933273,
#    0.030031798407435417,
#    0.8618051409721375,
#    3.9850428379395453e-07],
#   'predicted_label': 2},
#  {'score': [0.003921386785805225,
#    0.9909662008285522,
#    0.0048432243056595325,
#    0.0002691989066079259],
#   'predicted_label': 1},
#  {'score': [0.0006071837269701064,
#    0.9857797622680664,
#    0.00987632479518652,
#    0.003736774669960141],
#   'predicted_label': 1},
#  {'score': [0.14215704798698425,
#    0.08229734003543854,
#    0.7755439877510071,
#    1.6188450899790041e-06],
#   'predicted_label': 2},
#  {'score': [0.9044991135597229,
#    0.037431444972753525,
#    0.05613249912858009,
#    0.0019369367510080338],
#   'predicted_label': 0},
#  {'score': [0.9350383877754211,
#    0.018579673022031784,
#    0.042503081262111664,
#    0.0038788598030805588],
#   'predicted_label': 0},
#  {'score': [0.9285393953323364,
#    0.03347056359052658,
#    0.036097995936870575,
#    0.0018920960137620568],
#   'predicted_label': 0},
#  {'score': [0.005723673850297928,
#    0.010155661962926388,
#    0.9841206073760986,
#    3.7545873965427745e-08],
#   'predicted_label': 2},
#  {'score': [0.9324434399604797,
#    0.013926238752901554,
#    0.042503971606492996,
#    0.011126321740448475],
#   'predicted_label': 0},
#  {'score': [0.8877664804458618,
#    0.050346601754426956,
#    0.05492652580142021,
#    0.0069603812880814075],
#   'predicted_label': 0},
#  {'score': [0.021832970902323723,
#    0.03151067718863487,
#    0.9466555118560791,
#    8.09664754797268e-07],
#   'predicted_label': 2},
#  {'score': [0.8906570076942444,
#    0.031748708337545395,
#    0.06172623112797737,
#    0.015868043527007103],
#   'predicted_label': 0},
#  {'score': [0.0026548407040536404,
#    0.05761870741844177,
#    0.9397258162498474,
#    6.974389634706313e-07],
#   'predicted_label': 2},
#  {'score': [0.7180331349372864,
#    0.1039673462510109,
#    0.10153444856405258,
#    0.07646503299474716],
#   'predicted_label': 0},
#  {'score': [0.002331216586753726,
#    0.02371962182223797,
#    0.000313495344016701,
#    0.9736356735229492],
#   'predicted_label': 3},
#  {'score': [0.042879655957221985,
#    0.9074589014053345,
#    0.04965538904070854,
#    6.051955551811261e-06],
#   'predicted_label': 1},
#  {'score': [0.05229131877422333,
#    0.2062351554632187,
#    0.7414498925209045,
#    2.3576747480547056e-05],
#   'predicted_label': 2},
#  {'score': [0.7481871843338013,
#    0.14093820750713348,
#    0.10239803045988083,
#    0.008476587012410164],
#   'predicted_label': 0},
#  {'score': [0.0011670986423268914,
#    0.18827712535858154,
#    0.8105490207672119,
#    6.730894710926805e-06],
#   'predicted_label': 2},
#  {'score': [0.7419465184211731,
#    0.03904077038168907,
#    0.2190125584602356,
#    1.3003575816128432e-07],
#   'predicted_label': 0},
#  {'score': [0.43438372015953064,
#    0.09325920045375824,
#    0.4723570942878723,
#    1.000000013351432e-10],
#   'predicted_label': 2},
#  {'score': [0.001037714653648436,
#    0.9900162220001221,
#    0.00547206774353981,
#    0.003474016208201647],
#   'predicted_label': 1},
#  {'score': [0.0006188912084326148,
#    0.9889113306999207,
#    0.006369528826326132,
#    0.004100201651453972],
#   'predicted_label': 1},
#  {'score': [0.4625508785247803,
#    0.11460146307945251,
#    0.4228476881980896,
#    1.000000013351432e-10],
#   'predicted_label': 0},
#  {'score': [0.01263339165598154,
#    0.0536208413541317,
#    0.0015344250714406371,
#    0.9322113394737244],
#   'predicted_label': 3},
#  {'score': [0.04424922168254852,
#    0.07152937352657318,
#    0.8842192888259888,
#    2.1109224235260626e-06],
#   'predicted_label': 2},
#  {'score': [0.1464672088623047,
#    0.07211394608020782,
#    0.7814181447029114,
#    6.798180152145505e-07],
#   'predicted_label': 2},
#  {'score': [0.7249059677124023,
#    0.13650710880756378,
#    0.08737053722143173,
#    0.05121636390686035],
#   'predicted_label': 0},
#  {'score': [0.0006804202566854656,
#    0.9862010478973389,
#    0.01109167281538248,
#    0.002026870148256421],
#   'predicted_label': 1},
#  {'score': [0.2191583663225174,
#    0.19326867163181305,
#    0.5875517725944519,
#    2.118147494911682e-05],
#   'predicted_label': 2},
#  {'score': [0.5371448993682861,
#    0.24297945201396942,
#    0.2198752760887146,
#    3.1591153515364567e-07],
#   'predicted_label': 0},
#  {'score': [0.015148633159697056,
#    0.030048750340938568,
#    0.9548020362854004,
#    5.96664449403761e-07],
#   'predicted_label': 2},
#  {'score': [0.8180467486381531,
#    0.0821281373500824,
#    0.09752064943313599,
#    0.0023044291883707047],
#   'predicted_label': 0},
#  {'score': [0.4707423150539398,
#    0.1436392366886139,
#    0.385617196559906,
#    1.2886674767287332e-06],
#   'predicted_label': 0},
#  {'score': [0.005242071580141783,
#    0.9585536122322083,
#    0.033090781420469284,
#    0.0031134982127696276],
#   'predicted_label': 1},
#  {'score': [0.019031338393688202,
#    0.07992605119943619,
#    0.9010401964187622,
#    2.3660363694943953e-06],
#   'predicted_label': 2},
#  {'score': [0.5663892030715942,
#    0.07757782936096191,
#    0.35589244961738586,
#    0.00014053404447622597],
#   'predicted_label': 0},
#  {'score': [0.019000191241502762,
#    0.09042290598154068,
#    0.8905733227729797,
#    3.5384257444093237e-06],
#   'predicted_label': 2},
#  {'score': [0.11141733080148697,
#    0.7162431478500366,
#    0.17144812643527985,
#    0.0008913904312066734],
#   'predicted_label': 1},
#  {'score': [0.9286993741989136,
#    0.032017264515161514,
#    0.03764332830905914,
#    0.0016400483436882496],
#   'predicted_label': 0},
#  {'score': [0.3016088902950287,
#    0.04372765123844147,
#    0.654659628868103,
#    3.872429715556791e-06],
#   'predicted_label': 2},
#  {'score': [0.22753526270389557,
#    0.056637439876794815,
#    0.7158271074295044,
#    1.7334664903501107e-07],
#   'predicted_label': 2},
#  {'score': [0.006462648045271635,
#    0.06576423346996307,
#    0.0016396892024204135,
#    0.9261334538459778],
#   'predicted_label': 3},
#  {'score': [0.07000765949487686,
#    0.10255302488803864,
#    0.8274346590042114,
#    4.634898687072564e-06],
#   'predicted_label': 2},
#  {'score': [0.009626394137740135,
#    0.9887182712554932,
#    0.0012701333034783602,
#    0.00038523314287886024],
#   'predicted_label': 1},
#  {'score': [0.9429447054862976,
#    0.007875059731304646,
#    0.03797411918640137,
#    0.011206078343093395],
#   'predicted_label': 0},
#  {'score': [0.12497492879629135,
#    0.4031224846839905,
#    0.4718497097492218,
#    5.291228080750443e-05],
#   'predicted_label': 2},
#  {'score': [0.0323886014521122,
#    0.9324051737785339,
#    0.035081617534160614,
#    0.00012455582327675074],
#   'predicted_label': 1},
#  {'score': [0.7991002202033997,
#    0.00024585536448284984,
#    0.20065395534038544,
#    2.9567506776295716e-10],
#   'predicted_label': 0},
#  {'score': [0.010020491667091846,
#    0.9735190868377686,
#    0.016259822994470596,
#    0.00020055024651810527],
#   'predicted_label': 1},
#  {'score': [0.20889370143413544,
#    0.12461603432893753,
#    0.6664852499961853,
#    4.964376785210334e-06],
#   'predicted_label': 2},
#  {'score': [0.0032752754632383585,
#    0.9952194094657898,
#    0.000730051368009299,
#    0.0007752033416181803],
#   'predicted_label': 1},
#  {'score': [0.10176011174917221,
#    0.09650032222270966,
#    0.8017395734786987,
#    3.362911371596056e-08],
#   'predicted_label': 2},
#  {'score': [0.03149580582976341,
#    0.039399318397045135,
#    0.9290080666542053,
#    9.688330464996397e-05],
#   'predicted_label': 2},
#  {'score': [0.13498733937740326,
#    0.10463453084230423,
#    0.7603752017021179,
#    2.9903280847065616e-06],
#   'predicted_label': 2},
#  {'score': [0.30071356892585754,
#    0.15653137862682343,
#    0.542749285697937,
#    5.770539246441331e-06],
#   'predicted_label': 2},
#  {'score': [0.04880860447883606,
#    0.8945488929748535,
#    0.0565967857837677,
#    4.572595935314894e-05],
#   'predicted_label': 1},
#  {'score': [0.23382090032100677,
#    0.12275354564189911,
#    0.6434230804443359,
#    2.53026496466191e-06],
#   'predicted_label': 2},
#  {'score': [0.905339241027832,
#    0.028959665447473526,
#    0.054143887013196945,
#    0.011557206511497498],
#   'predicted_label': 0},
#  {'score': [0.1322818398475647,
#    0.03618134930729866,
#    0.8315367698669434,
#    7.421108705329971e-08],
#   'predicted_label': 2},
#  {'score': [0.007375346962362528,
#    0.06649984419345856,
#    0.0019413994159549475,
#    0.9241834282875061],
#   'predicted_label': 3},
#  {'score': [0.26499035954475403,
#    0.03252701833844185,
#    0.7024824023246765,
#    2.2737093274827203e-07],
#   'predicted_label': 2},
#  {'score': [0.08206349611282349,
#    0.7911875247955322,
#    0.12674836814403534,
#    5.793117452412844e-07],
#   'predicted_label': 1},
#  {'score': [0.928511381149292,
#    0.025764375925064087,
#    0.03987231105566025,
#    0.005851882975548506],
#   'predicted_label': 0},
#  {'score': [0.10608293861150742,
#    0.04375489428639412,
#    0.8501620888710022,
#    9.803551392906229e-08],
#   'predicted_label': 2},
#  {'score': [0.18946364521980286,
#    0.31496715545654297,
#    0.4953210651874542,
#    0.0002481792471371591],
#   'predicted_label': 2},
#  {'score': [0.29520344734191895,
#    0.3579593598842621,
#    0.3468359708786011,
#    1.2003343954347656e-06],
#   'predicted_label': 1},
#  {'score': [0.017194634303450584,
#    0.06443005800247192,
#    0.9183739423751831,
#    1.3621375956063275e-06],
#   'predicted_label': 2},
#  {'score': [0.8135086297988892,
#    0.05206075310707092,
#    0.1341235488653183,
#    0.000307040405459702],
#   'predicted_label': 0},
#  {'score': [0.000470878672786057,
#    0.9874786138534546,
#    0.00793299451470375,
#    0.0041174753569066525],
#   'predicted_label': 1},
#  {'score': [0.3539557456970215,
#    0.3188241720199585,
#    0.09555380046367645,
#    0.23166631162166595],
#   'predicted_label': 0},
#  {'score': [0.03219584748148918,
#    0.16444414854049683,
#    0.8033417463302612,
#    1.832093948905822e-05],
#   'predicted_label': 2},
#  {'score': [0.6793497204780579,
#    0.15462560951709747,
#    0.08714006096124649,
#    0.07888463139533997],
#   'predicted_label': 0},
#  {'score': [0.002429228276014328,
#    0.9767501950263977,
#    0.020676301792263985,
#    0.00014424696564674377],
#   'predicted_label': 1},
#  {'score': [0.30319744348526,
#    0.1263788342475891,
#    0.5704154968261719,
#    8.279474968730938e-06],
#   'predicted_label': 2},
#  {'score': [0.6568024158477783,
#    0.20766544342041016,
#    0.1285451054573059,
#    0.006987003143876791],
#   'predicted_label': 0},
#  {'score': [0.8150551915168762,
#    0.08868163079023361,
#    0.09625473618507385,
#    8.458609954686835e-06],
#   'predicted_label': 0},
#  {'score': [0.29209718108177185,
#    0.12691093981266022,
#    0.5809799432754517,
#    1.1920221368200146e-05],
#   'predicted_label': 2},
#  {'score': [0.17305034399032593,
#    0.3271115720272064,
#    0.49969494342803955,
#    0.00014312028361018747],
#   'predicted_label': 2},
#  {'score': [0.5065076947212219,
#    0.023499589413404465,
#    0.4699926972389221,
#    1.000000013351432e-10],
#   'predicted_label': 0},
#  {'score': [0.005260844249278307,
#    0.020663674920797348,
#    0.0006410290952771902,
#    0.9734345078468323],
#   'predicted_label': 3},
#  {'score': [0.9917007684707642,
#    0.0027860095724463463,
#    0.00524966511875391,
#    0.0002635335549712181],
#   'predicted_label': 0},
#  {'score': [0.013471630401909351,
#    0.07971366494894028,
#    0.9068133234977722,
#    1.3556431213146425e-06],
#   'predicted_label': 2},
#  {'score': [0.012355918064713478,
#    0.11783664673566818,
#    0.8698052167892456,
#    2.275029601150891e-06],
#   'predicted_label': 2},
#  {'score': [0.020931323990225792,
#    0.9482465982437134,
#    0.030808616429567337,
#    1.3491220670402981e-05],
#   'predicted_label': 1},
#  {'score': [0.3322749733924866,
#    0.04072606936097145,
#    0.6269983649253845,
#    5.550892865358037e-07],
#   'predicted_label': 2},
#  {'score': [0.008518367074429989,
#    0.06696748733520508,
#    0.0019997633062303066,
#    0.9225143790245056],
#   'predicted_label': 3},
#  {'score': [0.0006051793461665511,
#    0.9862234592437744,
#    0.00417036097496748,
#    0.00900100264698267],
#   'predicted_label': 1},
#  {'score': [0.8010407090187073,
#    0.03357386216521263,
#    0.16537253558635712,
#    1.2894070096081123e-05],
#   'predicted_label': 0},
#  {'score': [0.1625109314918518,
#    0.06805246323347092,
#    0.7694345116615295,
#    2.086367885567597e-06],
#   'predicted_label': 2},
#  {'score': [0.8652289509773254,
#    0.06469092518091202,
#    0.06998766958713531,
#    9.24693449633196e-05],
#   'predicted_label': 0},
#  {'score': [0.07374206930398941,
#    0.8484669327735901,
#    0.07336268573999405,
#    0.004428274463862181],
#   'predicted_label': 1},
#  {'score': [0.9840351939201355,
#    0.005393754690885544,
#    0.010356457903981209,
#    0.00021463602024596184],
#   'predicted_label': 0},
#  {'score': [0.8548204898834229,
#    0.0294781606644392,
#    0.11570028215646744,
#    1.05012418316619e-06],
#   'predicted_label': 0},
#  {'score': [0.81517493724823,
#    0.007314498070627451,
#    0.17751048505306244,
#    5.1274078316509986e-08],
#   'predicted_label': 0},
#  {'score': [0.10691411793231964,
#    0.08067407459020615,
#    0.8124088644981384,
#    2.9479149361577583e-06],
#   'predicted_label': 2},
#  {'score': [0.10535766929388046,
#    0.79262375831604,
#    0.10108064115047455,
#    0.000937958771828562],
#   'predicted_label': 1},
#  {'score': [0.16857390105724335,
#    0.31038978695869446,
#    0.5208664536476135,
#    0.00016981545195449144],
#   'predicted_label': 2},
#  {'score': [0.44355374574661255,
#    0.00220446172170341,
#    0.5542417764663696,
#    1.2106351476859345e-08],
#   'predicted_label': 2},
#  {'score': [0.011592093855142593,
#    0.6129133105278015,
#    0.374946653842926,
#    0.0005479418323375285],
#   'predicted_label': 1},
#  {'score': [0.025416476652026176,
#    0.13392195105552673,
#    0.84065842628479,
#    3.15865463562659e-06],
#   'predicted_label': 2},
#  {'score': [0.21771328151226044,
#    0.0726594552397728,
#    0.7096195816993713,
#    7.767478564346675e-06],
#   'predicted_label': 2},
#  {'score': [0.28842830657958984,
#    0.3477786183357239,
#    0.36379167437553406,
#    1.3989622402732493e-06],
#   'predicted_label': 2},
#  {'score': [0.0012624622322618961,
#    0.0004176161892246455,
#    0.9983199238777161,
#    5.260953339636387e-10],
#   'predicted_label': 2},
#  {'score': [0.07116580009460449,
#    0.14174851775169373,
#    0.7869951128959656,
#    9.060745651368052e-05],
#   'predicted_label': 2},
#  {'score': [0.30425944924354553,
#    0.5626620650291443,
#    0.1330551654100418,
#    2.324170600331854e-05],
#   'predicted_label': 1},
#  {'score': [0.010627420619130135,
#    0.9295693039894104,
#    0.05976149067282677,
#    4.179465031484142e-05],
#   'predicted_label': 1},
#  {'score': [0.08344309031963348,
#    0.17840060591697693,
#    0.738156259059906,
#    5.372335909470394e-09],
#   'predicted_label': 2},
#  {'score': [0.10466156899929047,
#    0.007112219464033842,
#    0.8882262110710144,
#    2.6065515967843567e-08],
#   'predicted_label': 2},
#  {'score': [0.18380804359912872,
#    0.25404849648475647,
#    0.5621297359466553,
#    1.3769801626040135e-05],
#   'predicted_label': 2},
#  {'score': [0.8357731699943542,
#    0.030572695657610893,
#    0.13365255296230316,
#    1.6199226138269296e-06],
#   'predicted_label': 0},
#  {'score': [0.12843744456768036,
#    0.14742441475391388,
#    0.7241309285163879,
#    7.170215212681796e-06],
#   'predicted_label': 2},
#  {'score': [0.9183260798454285,
#    0.02916174940764904,
#    0.05251207947731018,
#    1.2553900319289824e-07],
#   'predicted_label': 0},
#  {'score': [0.8956307172775269,
#    0.04823717847466469,
#    0.04862942174077034,
#    0.007502661552280188],
#   'predicted_label': 0},
#  {'score': [0.006225257646292448,
#    0.1147908940911293,
#    0.8789475560188293,
#    3.62999016942922e-05],
#   'predicted_label': 2},
#  {'score': [0.08827777206897736,
#    0.15053045749664307,
#    0.7611917853355408,
#    2.3088562173256832e-09],
#   'predicted_label': 2},
#  {'score': [0.46119967103004456,
#    0.005091638769954443,
#    0.5337086319923401,
#    6.411440978126848e-08],
#   'predicted_label': 2},
#  {'score': [0.7274900674819946,
#    0.09437253326177597,
#    0.09508740901947021,
#    0.08304997533559799],
#   'predicted_label': 0},
#  {'score': [0.9372705817222595,
#    0.00549816619604826,
#    0.05723123624920845,
#    4.166017530948807e-10],
#   'predicted_label': 0},
#  {'score': [0.7436951398849487,
#    0.09272438287734985,
#    0.09446919709444046,
#    0.06911125779151917],
#   'predicted_label': 0},
#  {'score': [0.006100017577409744,
#    0.9667073488235474,
#    0.025695936754345894,
#    0.0014966874150559306],
#   'predicted_label': 1},
#  {'score': [0.5303270220756531,
#    0.2314128875732422,
#    0.23825058341026306,
#    9.466943993174937e-06],
#   'predicted_label': 0},
#  {'score': [0.08546772599220276,
#    0.07379152625799179,
#    0.8407405018806458,
#    3.304078290966572e-07],
#   'predicted_label': 2},
#  {'score': [0.006432561203837395,
#    0.09882595390081406,
#    0.8947393894195557,
#    2.1705752715206472e-06],
#   'predicted_label': 2},
#  {'score': [0.095637746155262,
#    0.046879976987838745,
#    0.8574821352958679,
#    1.2253501324721583e-07],
#   'predicted_label': 2},
#  {'score': [0.3437007665634155,
#    0.027604859322309494,
#    0.6286939382553101,
#    4.3896980628232996e-07],
#   'predicted_label': 2},
#  {'score': [0.29271337389945984,
#    0.04191182181239128,
#    0.6653740406036377,
#    7.279754754563328e-07],
#   'predicted_label': 2},
#  {'score': [0.8309924006462097,
#    0.14141730964183807,
#    0.027589596807956696,
#    6.94142613610893e-07],
#   'predicted_label': 0},
#  {'score': [0.1376829445362091,
#    0.08645997941493988,
#    0.775855302810669,
#    1.7688577145236195e-06],
#   'predicted_label': 2},
#  {'score': [0.004439875949174166,
#    0.0073866150341928005,
#    0.9881735444068909,
#    3.120739577866516e-08],
#   'predicted_label': 2},
#  {'score': [0.0031684760469943285,
#    0.041840262711048126,
#    0.9549882411956787,
#    2.9499310585379135e-06],
#   'predicted_label': 2},
#  {'score': [0.49754977226257324,
#    0.0327194519340992,
#    0.4697307050228119,
#    1.000000013351432e-10],
#   'predicted_label': 0},
#  {'score': [0.7804528474807739,
#    0.02289385162293911,
#    0.19665326178073883,
#    5.467655217472611e-09],
#   'predicted_label': 0},
#  {'score': [0.06824052333831787,
#    0.02135530672967434,
#    0.9104039669036865,
#    2.7556583859222883e-07],
#   'predicted_label': 2},
#  {'score': [0.08465272933244705,
#    0.4274328649044037,
#    0.48790809512138367,
#    6.327408300421666e-06],
#   'predicted_label': 2},
#  {'score': [0.6354167461395264,
#    0.212138831615448,
#    0.14785094559192657,
#    0.00459351297467947],
#   'predicted_label': 0},
#  {'score': [0.056702371686697006,
#    0.28952717781066895,
#    0.6537376046180725,
#    3.286565697635524e-05],
#   'predicted_label': 2},
#  {'score': [0.08440407365560532,
#    0.7717676758766174,
#    0.1428575962781906,
#    0.0009706378914415836],
#   'predicted_label': 1},
#  {'score': [0.9302395582199097,
#    0.019359080120921135,
#    0.04366934299468994,
#    0.006732042878866196],
#   'predicted_label': 0},
#  {'score': [0.019062364473938942,
#    0.08917028456926346,
#    0.8917615413665771,
#    5.822856110171415e-06],
#   'predicted_label': 2},
#  {'score': [0.012960034422576427,
#    0.9719688296318054,
#    0.014184962026774883,
#    0.0008861548267304897],
#   'predicted_label': 1},
#  {'score': [0.5442185997962952,
#    0.13734868168830872,
#    0.31818822026252747,
#    0.0002445181889925152],
#   'predicted_label': 0},
#  {'score': [0.5785765051841736,
#    0.1219739243388176,
#    0.11747828125953674,
#    0.18197126686573029],
#   'predicted_label': 0},
#  {'score': [0.8777732253074646,
#    0.000430117710493505,
#    0.1217966303229332,
#    3.038608531458209e-10],
#   'predicted_label': 0},
#  {'score': [0.001889986451715231,
#    0.9221935272216797,
#    0.07507923245429993,
#    0.0008372202864848077],
#   'predicted_label': 1},
#  {'score': [0.110612653195858,
#    0.4313427209854126,
#    0.4580134451389313,
#    3.1116454920265824e-05],
#   'predicted_label': 2},
#  {'score': [0.002655056770890951,
#    0.04595667123794556,
#    0.0019114594906568527,
#    0.9494767785072327],
#   'predicted_label': 3},
#  {'score': [0.5732066631317139,
#    0.09271383285522461,
#    0.33401164412498474,
#    6.782722630305216e-05],
#   'predicted_label': 0},
#  {'score': [0.007976588793098927,
#    0.028426771983504295,
#    0.0007939419010654092,
#    0.9628027081489563],
#   'predicted_label': 3},
#  {'score': [0.9264504909515381,
#    0.007220730651170015,
#    0.06632883846759796,
#    1.973915253472569e-09],
#   'predicted_label': 0},
#  {'score': [0.5489380955696106,
#    0.25760990381240845,
#    0.11270027607679367,
#    0.08075176179409027],
#   'predicted_label': 0},
#  {'score': [0.02730286866426468,
#    0.002911096904426813,
#    0.9697859883308411,
#    5.7635087813423524e-08],
#   'predicted_label': 2},
#  {'score': [0.0007367937359958887,
#    0.9939708113670349,
#    0.004132973030209541,
#    0.001159393461421132],
#   'predicted_label': 1},
#  {'score': [0.020464986562728882,
#    0.08311313390731812,
#    0.8964207768440247,
#    1.0870809319385444e-06],
#   'predicted_label': 2},
#  {'score': [0.30574673414230347,
#    0.16931118071079254,
#    0.5249416828155518,
#    4.257440195942763e-07],
#   'predicted_label': 2},
#  {'score': [0.016229728236794472,
#    0.9575047492980957,
#    0.026238106191158295,
#    2.7442178179626353e-05],
#   'predicted_label': 1},
#  {'score': [0.783973217010498,
#    0.10461542755365372,
#    0.09141003340482712,
#    0.02000129036605358],
#   'predicted_label': 0},
#  {'score': [0.02433997578918934,
#    0.14071302115917206,
#    0.8349434733390808,
#    3.550745304892189e-06],
#   'predicted_label': 2},
#  {'score': [0.9544565081596375,
#    0.014938200823962688,
#    0.030604597181081772,
#    6.868321520414611e-07],
#   'predicted_label': 0},
#  {'score': [0.5403544902801514,
#    0.02155035175383091,
#    0.4380951225757599,
#    1.000000013351432e-10],
#   'predicted_label': 0},
#  {'score': [0.01083200704306364,
#    0.9301325082778931,
#    0.0586579404771328,
#    0.0003774935903493315],
#   'predicted_label': 1},
#  {'score': [0.00442610215395689,
#    0.9884265661239624,
#    0.0058939410373568535,
#    0.0012534140842035413],
#   'predicted_label': 1},
#  {'score': [0.0740237683057785,
#    0.8924676179885864,
#    0.03278592973947525,
#    0.0007226305897347629],
#   'predicted_label': 1},
#  {'score': [0.9226397275924683,
#    0.022901983931660652,
#    0.04340502992272377,
#    0.01105326134711504],
#   'predicted_label': 0},
#  {'score': [0.09994290769100189,
#    0.14244374632835388,
#    0.7575964331626892,
#    1.6908210454857908e-05],
#   'predicted_label': 2},
#  {'score': [0.0013783283066004515,
#    0.03568784147500992,
#    0.9629319310188293,
#    1.8928162717202213e-06],
#   'predicted_label': 2},
#  {'score': [0.3104079067707062,
#    0.03795676678419113,
#    0.6516342759132385,
#    9.871940847006044e-07],
#   'predicted_label': 2},
#  {'score': [0.33250853419303894,
#    0.30956724286079407,
#    0.357923299074173,
#    9.142601697931241e-07],
#   'predicted_label': 2},
#  {'score': [0.33898037672042847,
#    0.02739972062408924,
#    0.633619487285614,
#    4.142415264141164e-07],
#   'predicted_label': 2},
#  {'score': [0.3926451802253723,
#    0.3134951591491699,
#    0.2937897741794586,
#    6.991017289692536e-05],
#   'predicted_label': 0},
#  {'score': [0.06105805188417435,
#    0.10854055732488632,
#    0.8303989171981812,
#    2.3939478523971047e-06],
#   'predicted_label': 2},
#  {'score': [0.16441082954406738,
#    0.33515316247940063,
#    0.5002089738845825,
#    0.00022703639115206897],
#   'predicted_label': 2},
#  {'score': [0.8690025806427002,
#    0.058990344405174255,
#    0.06686965376138687,
#    0.005137401167303324],
#   'predicted_label': 0},
#  {'score': [0.8466945886611938,
#    7.926289981696755e-05,
#    0.15322618186473846,
#    1.000000013351432e-10],
#   'predicted_label': 0},
#  {'score': [0.007968764752149582,
#    0.037313513457775116,
#    0.0010141723323613405,
#    0.9537035226821899],
#   'predicted_label': 3},
#  {'score': [0.5141668319702148,
#    0.17018181085586548,
#    0.3151010274887085,
#    0.0005503669381141663],
#   'predicted_label': 0},
#  {'score': [0.8133284449577332,
#    0.044182129204273224,
#    0.1414090394973755,
#    0.0010803824989125133],
#   'predicted_label': 0},
#  {'score': [0.047935180366039276,
#    0.018622076138854027,
#    0.9334425926208496,
#    1.3886098315651907e-07],
#   'predicted_label': 2},
#  {'score': [0.0027352608740329742,
#    0.13701650500297546,
#    0.8602305054664612,
#    1.7729373212205246e-05],
#   'predicted_label': 2},
#  {'score': [0.5295644998550415,
#    0.07300630956888199,
#    0.39737364649772644,
#    5.548401168198325e-05],
#   'predicted_label': 0},
#  {'score': [0.031884532421827316,
#    0.875886082649231,
#    0.09222792088985443,
#    1.4837371509202057e-06],
#   'predicted_label': 1},
#  {'score': [0.8997587561607361,
#    0.03425411507487297,
#    0.06598705798387527,
#    5.5419015154711815e-08],
#   'predicted_label': 0},
#  {'score': [0.07900724560022354,
#    0.046027906239032745,
#    0.8749630451202393,
#    1.813134645090031e-06],
#   'predicted_label': 2},
#  {'score': [0.8646138906478882,
#    0.06162477284669876,
#    0.07198120653629303,
#    0.0017801235662773252],
#   'predicted_label': 0},
#  {'score': [0.04538988322019577,
#    0.07722382247447968,
#    0.8773840069770813,
#    2.3159079773904523e-06],
#   'predicted_label': 2},
#  {'score': [0.3219454884529114,
#    0.21539579331874847,
#    0.4626457095146179,
#    1.298358074564021e-05],
#   'predicted_label': 2},
#  {'score': [0.017525654286146164,
#    0.9660741686820984,
#    0.016346100717782974,
#    5.407687422120944e-05],
#   'predicted_label': 1},
#  {'score': [0.9367749691009521,
#    0.014045280404388905,
#    0.04475590959191322,
#    0.004423836246132851],
#   'predicted_label': 0},
#  {'score': [0.43683725595474243,
#    0.05738293379545212,
#    0.5057797431945801,
#    1.000000013351432e-10],
#   'predicted_label': 2},
#  {'score': [0.21692568063735962,
#    0.04463065788149834,
#    0.7384435534477234,
#    1.0270086647778953e-07],
#   'predicted_label': 2},
#  {'score': [0.004705537110567093,
#    0.9913884401321411,
#    0.0036789029836654663,
#    0.00022715493105351925],
#   'predicted_label': 1},
#  {'score': [0.6075882315635681,
#    0.006441864185035229,
#    0.38596948981285095,
#    3.757788817893015e-07],
#   'predicted_label': 0},
#  {'score': [0.0050175790674984455,
#    0.0350213460624218,
#    0.0005993568920530379,
#    0.9593616724014282],
#   'predicted_label': 3},
#  {'score': [0.9092167019844055,
#    0.035628415644168854,
#    0.052979521453380585,
#    0.002175356727093458],
#   'predicted_label': 0},
#  {'score': [0.4935758113861084,
#    0.2511618137359619,
#    0.1005353108048439,
#    0.1547270119190216],
#   'predicted_label': 0},
#  {'score': [0.620182991027832,
#    0.04239966347813606,
#    0.337417334318161,
#    2.191947423568763e-08],
#   'predicted_label': 0},
#  {'score': [0.11871015280485153,
#    0.8220032453536987,
#    0.056996822357177734,
#    0.002289764117449522],
#   'predicted_label': 1},
#  {'score': [0.8356510996818542,
#    0.03319621831178665,
#    0.1311504989862442,
#    2.180363480874803e-06],
#   'predicted_label': 0},
#  {'score': [0.3501530587673187,
#    0.36345139145851135,
#    0.286380797624588,
#    1.4780823221371975e-05],
#   'predicted_label': 1},
#  {'score': [0.02516169100999832,
#    0.9620272517204285,
#    0.012352321296930313,
#    0.0004587684234138578],
#   'predicted_label': 1},
#  {'score': [0.30482521653175354,
#    0.09957781434059143,
#    0.5955969095230103,
#    1.2137203242446049e-08],
#   'predicted_label': 2},
#  {'score': [0.9426095485687256,
#    0.02487613633275032,
#    0.02955327369272709,
#    0.002961037214845419],
#   'predicted_label': 0},
#  {'score': [0.025098515674471855,
#    0.8546925783157349,
#    0.11935309320688248,
#    0.0008557977271266282],
#   'predicted_label': 1},
#  {'score': [0.0008471776382066309,
#    0.9905733466148376,
#    0.0054723466746509075,
#    0.0031071268022060394],
#   'predicted_label': 1},
#  {'score': [0.008085718378424644,
#    0.025965645909309387,
#    0.0007339119911193848,
#    0.9652147889137268],
#   'predicted_label': 3},
#  {'score': [0.43821293115615845,
#    0.1736902892589569,
#    0.38809633255004883,
#    4.819923447030305e-07],
#   'predicted_label': 0},
#  {'score': [0.024654394015669823,
#    0.9473605155944824,
#    0.027721386402845383,
#    0.0002637690049596131],
#   'predicted_label': 1},
#  {'score': [0.4558217525482178,
#    0.05768807232379913,
#    0.4864901900291443,
#    1.000000013351432e-10],
#   'predicted_label': 2},
#  {'score': [0.8825746178627014,
#    0.06988055258989334,
#    0.042963624000549316,
#    0.0045811827294528484],
#   'predicted_label': 0},
#  {'score': [0.00741232093423605,
#    0.05113304406404495,
#    0.001683271024376154,
#    0.9397714138031006],
#   'predicted_label': 3},
#  {'score': [0.006079545710235834,
#    0.03659743815660477,
#    0.0007028261898085475,
#    0.9566201567649841],
#   'predicted_label': 3},
#  {'score': [0.920769453048706,
#    0.026582572609186172,
#    0.05264444276690483,
#    3.5385605769988615e-06],
#   'predicted_label': 0},
#  {'score': [0.06008908152580261,
#    0.8549911379814148,
#    0.07004661113023758,
#    0.014873218722641468],
#   'predicted_label': 1},
#  {'score': [0.455113023519516,
#    0.03889448195695877,
#    0.5059925317764282,
#    1.651395964419322e-10],
#   'predicted_label': 2},
#  {'score': [0.9567039608955383,
#    0.016010474413633347,
#    0.024390552192926407,
#    0.0028949915431439877],
#   'predicted_label': 0},
#  {'score': [0.8613307476043701,
#    0.06839282065629959,
#    0.06945150345563889,
#    0.0008249119273386896],
#   'predicted_label': 0},
#  {'score': [0.17205509543418884,
#    0.06476333737373352,
#    0.7631794214248657,
#    2.149334250134416e-06],
#   'predicted_label': 2},
#  {'score': [0.023025410249829292,
#    0.9653406739234924,
#    0.011154457926750183,
#    0.00047949477448128164],
#   'predicted_label': 1},
#  {'score': [0.41583359241485596,
#    0.2698173522949219,
#    0.3142350912094116,
#    0.00011393454042263329],
#   'predicted_label': 0},
#  {'score': [0.5661426186561584,
#    0.24529050290584564,
#    0.18830657005310059,
#    0.00026030800654552877],
#   'predicted_label': 0},
#  {'score': [0.02239426039159298,
#    0.0497591570019722,
#    0.00106017233338207,
#    0.9267863631248474],
#   'predicted_label': 3},
#  {'score': [0.0062643191777169704,
#    0.0597124807536602,
#    0.001844086218625307,
#    0.9321790933609009],
#   'predicted_label': 3},
#  {'score': [0.7697759866714478,
#    0.10460534691810608,
#    0.08663412183523178,
#    0.0389845184981823],
#   'predicted_label': 0},
#  {'score': [0.3141005337238312,
#    0.1866648942232132,
#    0.49922823905944824,
#    6.3176189541991334e-06],
#   'predicted_label': 2},
#  {'score': [0.11888205260038376,
#    0.8246243596076965,
#    0.05641941726207733,
#    7.421537156915292e-05],
#   'predicted_label': 1},
#  {'score': [0.039949681609869,
#    0.5338699817657471,
#    0.4257933795452118,
#    0.00038690344081260264],
#   'predicted_label': 1},
#  {'score': [0.10054600238800049,
#    0.04476568102836609,
#    0.8546882271766663,
#    1.0580125575643251e-07],
#   'predicted_label': 2},
#  {'score': [0.7872458100318909,
#    0.03092155046761036,
#    0.18183259665966034,
#    8.10050582167321e-10],
#   'predicted_label': 0},
#  {'score': [0.6888719201087952,
#    0.05216818302869797,
#    0.10823837667703629,
#    0.150721475481987],
#   'predicted_label': 0},
#  {'score': [0.3165392279624939,
#    0.18622903525829315,
#    0.49722203612327576,
#    9.68413587543182e-06],
#   'predicted_label': 2},
#  {'score': [0.5383837223052979,
#    0.2610320448875427,
#    0.19942934811115265,
#    0.0011549164773896337],
#   'predicted_label': 0},
#  {'score': [0.9183858633041382,
#    0.009088284336030483,
#    0.020131852477788925,
#    0.052393991500139236],
#   'predicted_label': 0},
#  {'score': [0.7112349271774292,
#    0.003513540606945753,
#    0.28525155782699585,
#    6.7841909867638606e-09],
#   'predicted_label': 0},
#  {'score': [0.8811842203140259,
#    0.05259902402758598,
#    0.06517758220434189,
#    0.0010391628602519631],
#   'predicted_label': 0},
#  {'score': [0.006691431626677513,
#    0.8852625489234924,
#    0.10709144920110703,
#    0.0009545324719510972],
#   'predicted_label': 1},
#  {'score': [0.016415653750300407,
#    0.0019379074219614267,
#    0.9816464185714722,
#    1.4544501603097615e-08],
#   'predicted_label': 2},
#  {'score': [0.009214567951858044,
#    0.07525181770324707,
#    0.002758289920166135,
#    0.9127753376960754],
#   'predicted_label': 3},
#  {'score': [0.014249476604163647,
#    0.031860824674367905,
#    0.0007238772232085466,
#    0.9531658291816711],
#   'predicted_label': 3},
#  {'score': [0.6597394347190857,
#    0.0903535783290863,
#    0.24990619719028473,
#    8.214935292016889e-07],
#   'predicted_label': 0},
#  {'score': [0.3148145377635956,
#    0.18598145246505737,
#    0.499188631772995,
#    1.5340930985985324e-05],
#   'predicted_label': 2},
#  {'score': [0.89202880859375,
#    0.04883534833788872,
#    0.0522642508149147,
#    0.006871578749269247],
#   'predicted_label': 0},
#  {'score': [0.8859497308731079,
#    0.019938623532652855,
#    0.09214677661657333,
#    0.0019648915622383356],
#   'predicted_label': 0},
#  {'score': [0.7872023582458496,
#    0.17358601093292236,
#    0.026057960465550423,
#    0.01315367128700018],
#   'predicted_label': 0},
#  {'score': [0.031429748982191086,
#    0.9549873471260071,
#    0.008648681454360485,
#    0.004934258293360472],
#   'predicted_label': 1},
#  {'score': [0.028139350935816765,
#    0.9637897610664368,
#    0.0076928227208554745,
#    0.000378001102944836],
#   'predicted_label': 1},
#  {'score': [0.8980053663253784,
#    0.05231508985161781,
#    0.047991394996643066,
#    0.0016881454503163695],
#   'predicted_label': 0},
#  {'score': [0.8723781704902649,
#    0.0028797320555895567,
#    0.1247420683503151,
#    4.804706854599772e-09],
#   'predicted_label': 0},
#  {'score': [0.5379501581192017,
#    0.10140428692102432,
#    0.1626363843679428,
#    0.1980091631412506],
#   'predicted_label': 0},
#  {'score': [0.5364423990249634,
#    0.19257506728172302,
#    0.26854562759399414,
#    0.0024369657039642334],
#   'predicted_label': 0},
#  {'score': [0.8726357221603394,
#    0.05555087327957153,
#    0.06669369339942932,
#    0.005119670182466507],
#   'predicted_label': 0},
#  {'score': [0.914483368396759,
#    0.0376412458717823,
#    0.04766429215669632,
#    0.00021108581859152764],
#   'predicted_label': 0},
#  {'score': [0.07049714773893356,
#    0.007565065287053585,
#    0.9219370484352112,
#    7.54174266148766e-07],
#   'predicted_label': 2},
#  {'score': [0.004717306233942509,
#    0.9861582517623901,
#    0.008676066063344479,
#    0.00044844142394140363],
#   'predicted_label': 1},
#  {'score': [0.006723958533257246,
#    0.02777101658284664,
#    0.0006057157297618687,
#    0.9648993015289307],
#   'predicted_label': 3},
#  {'score': [0.958041250705719,
#    0.014661301858723164,
#    0.02729463204741478,
#    2.843130914698122e-06],
#   'predicted_label': 0},
#  {'score': [0.17200534045696259,
#    0.22231648862361908,
#    0.6056782007217407,
#    2.8112024708093486e-08],
#   'predicted_label': 2},
#  {'score': [0.8891403079032898,
#    0.05231237784028053,
#    0.03951043263077736,
#    0.019036881625652313],
#   'predicted_label': 0},
#  {'score': [0.021613596007227898,
#    0.10663194954395294,
#    0.8717537522315979,
#    7.019275471975561e-07],
#   'predicted_label': 2},
#  {'score': [0.8827363848686218,
#    0.03549442067742348,
#    0.07524667680263519,
#    0.006522501818835735],
#   'predicted_label': 0},
#  {'score': [0.18724539875984192,
#    0.09839203208684921,
#    0.7143499851226807,
#    1.2579251233546529e-05],
#   'predicted_label': 2},
#  {'score': [0.2549182176589966,
#    0.21197649836540222,
#    0.5331025123596191,
#    2.7527407837624196e-06],
#   'predicted_label': 2},
#  {'score': [0.9235048890113831,
#    0.035199519246816635,
#    0.04076377674937248,
#    0.0005318144685588777],
#   'predicted_label': 0},
#  {'score': [0.9691535234451294,
#    0.008004462346434593,
#    0.022605448961257935,
#    0.00023661291925236583],
#   'predicted_label': 0},
#  {'score': [0.001372212776914239,
#    0.9855925440788269,
#    0.012233829125761986,
#    0.0008014766499400139],
#   'predicted_label': 1},
#  {'score': [0.9226518273353577,
#    0.040285516530275345,
#    0.03387890011072159,
#    0.003183734370395541],
#   'predicted_label': 0},
#  {'score': [0.05487735569477081,
#    0.866663932800293,
#    0.0675608366727829,
#    0.010897922329604626],
#   'predicted_label': 1},
#  {'score': [0.3055521249771118,
#    0.26638585329055786,
#    0.42799505591392517,
#    6.691830640193075e-05],
#   'predicted_label': 2},
#  {'score': [0.9171499609947205,
#    0.03625005483627319,
#    0.041702233254909515,
#    0.004897790960967541],
#   'predicted_label': 0},
#  {'score': [0.8515446782112122,
#    0.07332885265350342,
#    0.0666147992014885,
#    0.008511699736118317],
#   'predicted_label': 0},
#  {'score': [0.007033271715044975,
#    0.1462765783071518,
#    0.8463970422744751,
#    0.000293076183879748],
#   'predicted_label': 2},
#  {'score': [0.37473225593566895,
#    0.14529968798160553,
#    0.479949414730072,
#    1.8599872419144958e-05],
#   'predicted_label': 2},
#  {'score': [0.6831684708595276,
#    0.07696647197008133,
#    0.2398277223110199,
#    3.7338020774768665e-05],
#   'predicted_label': 0},
#  {'score': [0.5718371272087097,
#    0.24603323638439178,
#    0.09950277954339981,
#    0.0826268345117569],
#   'predicted_label': 0},
#  {'score': [0.15718114376068115,
#    0.3912695646286011,
#    0.4514695405960083,
#    7.977780478540808e-05],
#   'predicted_label': 2},
#  {'score': [0.028672313317656517,
#    0.03035588189959526,
#    0.9409716725349426,
#    1.6265887836652837e-07],
#   'predicted_label': 2},
#  {'score': [0.012695176526904106,
#    0.21312296390533447,
#    0.7741364240646362,
#    4.5444336137734354e-05],
#   'predicted_label': 2},
#  {'score': [0.5125137567520142,
#    0.094476617872715,
#    0.39300966262817383,
#    1.000000013351432e-10],
#   'predicted_label': 0},
#  {'score': [0.35045093297958374,
#    0.005524835549294949,
#    0.6440242528915405,
#    1.9338632029075598e-08],
#   'predicted_label': 2},
#  {'score': [0.0047975038178265095,
#    0.07281357795000076,
#    0.002519543282687664,
#    0.9198693633079529],
#   'predicted_label': 3},
#  {'score': [0.008047861978411674,
#    0.044780433177948,
#    0.001160893589258194,
#    0.9460108280181885],
#   'predicted_label': 3},
#  {'score': [0.09607154130935669,
#    0.05093853920698166,
#    0.8529875874519348,
#    2.333732254555798e-06],
#   'predicted_label': 2},
#  {'score': [0.17085610330104828,
#    0.31830236315727234,
#    0.5107372999191284,
#    0.00010426166409160942],
#   'predicted_label': 2},
#  {'score': [0.7933486700057983,
#    0.12183279544115067,
#    0.08127551525831223,
#    0.0035430300049483776],
#   'predicted_label': 0},
#  {'score': [0.032550182193517685,
#    0.09555322676897049,
#    0.8718946576118469,
#    1.9351186892890837e-06],
#   'predicted_label': 2},
#  {'score': [0.9280666708946228,
#    0.03503505885601044,
#    0.03381727635860443,
#    0.00308095570653677],
#   'predicted_label': 0},
#  {'score': [0.8345987796783447,
#    0.05670199170708656,
#    0.1037033423781395,
#    0.004995891358703375],
#   'predicted_label': 0},
#  {'score': [0.6008557677268982,
#    0.05021190270781517,
#    0.34893232583999634,
#    1.9439783116581566e-08],
#   'predicted_label': 0},
#  {'score': [0.8259043097496033,
#    0.08832826465368271,
#    0.08570002019405365,
#    6.74321927363053e-05],
#   'predicted_label': 0},
#  {'score': [0.01917915977537632,
#    0.06245950236916542,
#    0.9183601140975952,
#    1.1952910199397593e-06],
#   'predicted_label': 2},
#  {'score': [0.7835994362831116,
#    0.1327679306268692,
#    0.07802523672580719,
#    0.005607374012470245],
#   'predicted_label': 0},
#  {'score': [0.030951377004384995,
#    0.9407715201377869,
#    0.02825353480875492,
#    2.36422274610959e-05],
#   'predicted_label': 1},
#  {'score': [0.11432913690805435,
#    0.745126485824585,
#    0.13973353803157806,
#    0.0008107697940431535],
#   'predicted_label': 1},
#  {'score': [0.037294626235961914,
#    0.8412544131278992,
#    0.12144213914871216,
#    8.783804332779255e-06],
#   'predicted_label': 1},
#  {'score': [0.4331463575363159,
#    0.35693517327308655,
#    0.20988740026950836,
#    3.104526695096865e-05],
#   'predicted_label': 0},
#  {'score': [0.9338650107383728,
#    0.016969528049230576,
#    0.03980119153857231,
#    0.009364226832985878],
#   'predicted_label': 0},
#  {'score': [0.680976927280426,
#    0.19712117314338684,
#    0.08851506561040878,
#    0.033386845141649246],
#   'predicted_label': 0},
#  {'score': [0.48418891429901123,
#    0.13452470302581787,
#    0.3812851011753082,
#    1.3228248008090304e-06],
#   'predicted_label': 0},
#  {'score': [0.04562031850218773,
#    0.49056240916252136,
#    0.4636041820049286,
#    0.00021313081379048526],
#   'predicted_label': 1},
#  {'score': [0.6457261443138123,
#    0.07416925579309464,
#    0.1311260610818863,
#    0.1489786058664322],
#   'predicted_label': 0},
#  {'score': [0.22676034271717072,
#    0.13062958419322968,
#    0.6425957083702087,
#    1.4362279216584284e-05],
#   'predicted_label': 2},
#  {'score': [0.9043201208114624,
#    0.051843222230672836,
#    0.04335639253258705,
#    0.0004803093906957656],
#   'predicted_label': 0},
#  {'score': [0.0027618955355137587,
#    0.023581361398100853,
#    0.0004453920992091298,
#    0.9732113480567932],
#   'predicted_label': 3},
#  {'score': [0.7913628816604614,
#    0.030070235952734947,
#    0.17856690287590027,
#    7.964763959478205e-09],
#   'predicted_label': 0},
#  {'score': [0.7963146567344666,
#    0.026049265637993813,
#    0.1776360720396042,
#    7.494949549879948e-09],
#   'predicted_label': 0},
#  {'score': [0.7528902888298035,
#    0.03781921789050102,
#    0.2092871367931366,
#    3.3170006190630374e-06],
#   'predicted_label': 0},
#  {'score': [0.0020848375279456377,
#    0.023455262184143066,
#    0.00033775524934753776,
#    0.9741221070289612],
#   'predicted_label': 3},
#  {'score': [0.5436326265335083,
#    0.11300908029079437,
#    0.34327444434165955,
#    8.389719732804224e-05],
#   'predicted_label': 0},
#  {'score': [0.9359509348869324,
#    0.014688908122479916,
#    0.0493599958717823,
#    1.1124282650598616e-07],
#   'predicted_label': 0},
#  {'score': [0.14647197723388672,
#    0.06158686801791191,
#    0.7919408082962036,
#    3.19207032362101e-07],
#   'predicted_label': 2},
#  {'score': [0.0012944857589900494,
#    0.011710502207279205,
#    0.00019639660604298115,
#    0.9867985844612122],
#   'predicted_label': 3},
#  {'score': [0.005286979954689741,
#    0.9868217706680298,
#    0.007843973115086555,
#    4.729469583253376e-05],
#   'predicted_label': 1},
#  {'score': [0.01922072097659111,
#    0.9515790939331055,
#    0.02916962467133999,
#    3.057957655983046e-05],
#   'predicted_label': 1},
#  {'score': [0.9055405855178833,
#    0.060322556644678116,
#    0.03208104893565178,
#    0.0020557946991175413],
#   'predicted_label': 0},
#  {'score': [0.22706519067287445,
#    0.1254032850265503,
#    0.6474990248680115,
#    3.2470477890456095e-05],
# ...
#    0.1338358372449875,
#    1.7047882465703879e-06],
#   'predicted_label': 0},
#  {'score': [0.43749725818634033,
#    0.18948592245578766,
#    0.37300053238868713,
#    1.627167330298107e-05],
#   'predicted_label': 0},
#  {'score': [0.4500894844532013,
#    0.11117126047611237,
#    0.43873921036720276,
#    1.000000013351432e-10],
#   'predicted_label': 0},
#  {'score': [0.34640175104141235,
#    0.030189288780093193,
#    0.6234083771705627,
#    5.042605266680766e-07],
#   'predicted_label': 2},
#  {'score': [0.37091174721717834,
#    0.1805422455072403,
#    0.07577217370271683,
#    0.37277382612228394],
#   'predicted_label': 3},
#  {'score': [0.6979159116744995,
#    0.12162430584430695,
#    0.1798759549856186,
#    0.0005838057841174304],
#   'predicted_label': 0},
#  {'score': [0.054810624569654465,
#    0.04614729806780815,
#    0.8990407586097717,
#    1.3632491118187318e-06],
#   'predicted_label': 2},
#  {'score': [0.00040526932571083307,
#    0.006535640452057123,
#    0.9930586814880371,
#    3.2494207857780566e-07],
#   'predicted_label': 2},
#  {'score': [0.07690681517124176,
#    0.8441190123558044,
#    0.06537611782550812,
#    0.01359802670776844],
#   'predicted_label': 1},
#  {'score': [0.007069802843034267,
#    0.0007210662006400526,
#    0.9922091364860535,
#    6.138034081004662e-09],
#   'predicted_label': 2},
#  {'score': [0.8347593545913696,
#    0.030983293429017067,
#    0.13425596058368683,
#    1.364221361654927e-06],
#   'predicted_label': 0},
#  {'score': [0.9560211896896362,
#    0.014721902087330818,
#    0.02725820615887642,
#    0.0019987167324870825],
#   'predicted_label': 0},
#  {'score': [0.23789267241954803,
#    0.5992741584777832,
#    0.1628204733133316,
#    1.2679889550781809e-05],
#   'predicted_label': 1},
#  {'score': [0.07320623844861984,
#    0.04278940334916115,
#    0.884002685546875,
#    1.6299459275614936e-06],
#   'predicted_label': 2},
#  {'score': [0.08633607625961304,
#    0.15398196876049042,
#    0.7595618963241577,
#    0.00012010525824734941],
#   'predicted_label': 2},
#  {'score': [0.7113657593727112,
#    0.04988354817032814,
#    0.23872576653957367,
#    2.493970350769814e-05],
#   'predicted_label': 0},
#  {'score': [0.8519821166992188,
#    0.08200549334287643,
#    0.056613288819789886,
#    0.009399093687534332],
#   'predicted_label': 0},
#  {'score': [0.0041418373584747314,
#    0.9890033602714539,
#    0.005169212818145752,
#    0.0016855945577844977],
#   'predicted_label': 1},
#  {'score': [0.9348793029785156,
#    0.027862031012773514,
#    0.037064000964164734,
#    0.00019466372032184154],
#   'predicted_label': 0},
#  {'score': [0.49560338258743286,
#    0.03679611161351204,
#    0.4676004946231842,
#    1.9146598195796116e-10],
#   'predicted_label': 0},
#  {'score': [0.9352010488510132,
#    0.023043250665068626,
#    0.04174087941646576,
#    1.4824344361841213e-05],
#   'predicted_label': 0},
#  {'score': [0.018658911809325218,
#    0.8881012797355652,
#    0.09303663671016693,
#    0.00020311592379584908],
#   'predicted_label': 1},
#  {'score': [0.5444158911705017,
#    0.08871036767959595,
#    0.1498425006866455,
#    0.21703128516674042],
#   'predicted_label': 0},
#  {'score': [0.176997572183609,
#    0.32684120535850525,
#    0.49598219990730286,
#    0.0001789906236808747],
#   'predicted_label': 2},
#  {'score': [0.5889604687690735,
#    0.2719234228134155,
#    0.13903412222862244,
#    8.206341590266675e-05],
#   'predicted_label': 0},
#  {'score': [0.20889735221862793,
#    0.06912259757518768,
#    0.7219482064247131,
#    3.188549817423336e-05],
#   'predicted_label': 2},
#  {'score': [0.0440308041870594,
#    0.846204936504364,
#    0.1096872016787529,
#    7.701580034336075e-05],
#   'predicted_label': 1},
#  {'score': [0.4277363419532776,
#    0.14543132483959198,
#    0.42683133482933044,
#    9.832564273892785e-07],
#   'predicted_label': 0},
#  {'score': [0.02876385860145092,
#    0.029540156945586205,
#    0.9416958093643188,
#    1.674325744716043e-07],
#   'predicted_label': 2},
#  {'score': [0.9301335215568542,
#    0.02609279565513134,
#    0.04357854276895523,
#    0.00019516087195370346],
#   'predicted_label': 0},
#  {'score': [0.5923849940299988,
#    0.009723789058625698,
#    0.3978905975818634,
#    5.415641908257385e-07],
#   'predicted_label': 0},
#  {'score': [0.32305362820625305,
#    0.038388870656490326,
#    0.6385570168495178,
#    4.841433565161424e-07],
#   'predicted_label': 2},
#  {'score': [0.3277418911457062,
#    0.269504189491272,
#    0.39298245310783386,
#    0.009771463461220264],
#   'predicted_label': 2},
#  {'score': [0.9532527327537537,
#    0.0051293401047587395,
#    0.04161787033081055,
#    5.2312323362002644e-08],
#   'predicted_label': 0},
#  {'score': [0.1458892524242401,
#    0.07803819328546524,
#    0.7760710120201111,
#    1.5734983662696322e-06],
#   'predicted_label': 2},
#  {'score': [0.9726222157478333,
#    0.016678258776664734,
#    0.010692795738577843,
#    6.7121545725967735e-06],
#   'predicted_label': 0},
#  {'score': [0.0010649283649399877,
#    0.9895313382148743,
#    0.005640260875225067,
#    0.003763461485505104],
#   'predicted_label': 1},
#  {'score': [0.4492909908294678,
#    0.16344547271728516,
#    0.16860774159431458,
#    0.21865582466125488],
#   'predicted_label': 0},
#  {'score': [0.10689830780029297,
#    0.8451898097991943,
#    0.047820284962654114,
#    9.162687638308853e-05],
#   'predicted_label': 1},
#  {'score': [0.7788962125778198,
#    0.1759183555841446,
#    0.04517018049955368,
#    1.5292680473066866e-05],
#   'predicted_label': 0},
#  {'score': [0.07651510089635849,
#    0.574361264705658,
#    0.34901517629623413,
#    0.00010845469660125673],
#   'predicted_label': 1},
#  {'score': [0.276760458946228,
#    0.15059824287891388,
#    0.572609007358551,
#    3.229066351195797e-05],
#   'predicted_label': 2},
#  {'score': [0.03263756260275841,
#    0.9495174884796143,
#    0.017744041979312897,
#    0.00010091927833855152],
#   'predicted_label': 1},
#  {'score': [0.9293933510780334,
#    0.016870703548192978,
#    0.05373578891158104,
#    1.6396022317621828e-07],
#   'predicted_label': 0},
#  {'score': [0.28054219484329224,
#    0.03782259300351143,
#    0.6816346645355225,
#    5.564554044212855e-07],
#   'predicted_label': 2},
#  {'score': [0.8908278942108154,
#    0.04226221516728401,
#    0.060666367411613464,
#    0.006243464536964893],
#   'predicted_label': 0},
#  {'score': [0.04122370854020119,
#    0.9488779306411743,
#    0.009560327976942062,
#    0.00033800757955759764],
#   'predicted_label': 1},
#  {'score': [0.9578871130943298,
#    0.004526357166469097,
#    0.03758642077445984,
#    5.190232954532803e-08],
#   'predicted_label': 0},
#  {'score': [0.08322039246559143,
#    0.743610680103302,
#    0.17316752672195435,
#    1.3722742551181e-06],
#   'predicted_label': 1},
#  {'score': [0.1426759511232376,
#    0.14649002254009247,
#    0.7108262181282043,
#    7.842473678465467e-06],
#   'predicted_label': 2},
#  {'score': [0.9245690107345581,
#    0.010692242532968521,
#    0.05612575262784958,
#    0.008613009005784988],
#   'predicted_label': 0},
#  {'score': [0.001310511026531458,
#    0.9891534447669983,
#    0.006692340597510338,
#    0.002843744121491909],
#   'predicted_label': 1},
#  {'score': [0.003903208067640662,
#    0.029461344704031944,
#    0.000590443261899054,
#    0.9660449624061584],
#   'predicted_label': 3},
#  {'score': [0.028557538986206055,
#    0.9294736385345459,
#    0.04184488579630852,
#    0.0001239153352798894],
#   'predicted_label': 1},
#  {'score': [0.0008147478802129626,
#    0.9846296310424805,
#    0.011573824100196362,
#    0.002981801750138402],
#   'predicted_label': 1},
#  {'score': [0.01144662406295538,
#    0.014250927604734898,
#    0.974302351474762,
#    6.209307912286022e-08],
#   'predicted_label': 2},
#  {'score': [0.010446890257298946,
#    0.0012826509773731232,
#    0.9882705211639404,
#    1.4210152166072021e-08],
#   'predicted_label': 2},
#  {'score': [0.8778475522994995,
#    0.0524890311062336,
#    0.06426314264535904,
#    0.005400313995778561],
#   'predicted_label': 0},
#  {'score': [0.002896934747695923,
#    0.9956585764884949,
#    0.0006768934545107186,
#    0.0007675468805246055],
#   'predicted_label': 1},
#  {'score': [0.6943800449371338,
#    0.13301794230937958,
#    0.0882311537861824,
#    0.08437084406614304],
#   'predicted_label': 0},
#  {'score': [0.021873051300644875,
#    0.06906561553478241,
#    0.9090607166290283,
#    6.40225266579364e-07],
#   'predicted_label': 2},
#  {'score': [0.02710237167775631,
#    0.9578556418418884,
#    0.014554108493030071,
#    0.00048791849985718727],
#   'predicted_label': 1},
#  {'score': [0.32375243306159973,
#    0.196467325091362,
#    0.4797796308994293,
#    6.107183594394883e-07],
#   'predicted_label': 2},
#  {'score': [0.7796798944473267,
#    0.13446469604969025,
#    0.08103055506944656,
#    0.004824848845601082],
#   'predicted_label': 0},
#  {'score': [0.0059256707318127155,
#    0.9559603929519653,
#    0.03793948516249657,
#    0.00017443325486965477],
#   'predicted_label': 1},
#  {'score': [0.27322661876678467,
#    0.36388665437698364,
#    0.1904139369726181,
#    0.1724727898836136],
#   'predicted_label': 1},
#  {'score': [0.9447968602180481,
#    0.00953715667128563,
#    0.03760668262839317,
#    0.008059302344918251],
#   'predicted_label': 0},
#  {'score': [0.16798828542232513,
#    0.05868972837924957,
#    0.7733181715011597,
#    3.814701358351158e-06],
#   'predicted_label': 2},
#  {'score': [0.0030909234192222357,
#    0.9952306747436523,
#    0.0007501101354137063,
#    0.0009283162653446198],
#   'predicted_label': 1},
#  {'score': [0.7779707908630371,
#    0.013608384877443314,
#    0.021617183461785316,
#    0.1868036538362503],
#   'predicted_label': 0},
#  {'score': [0.5096707344055176,
#    0.01968533545732498,
#    0.4706438481807709,
#    1.000000013351432e-10],
#   'predicted_label': 0},
#  {'score': [0.013516627252101898,
#    0.961792528629303,
#    0.024652888998389244,
#    3.798805846599862e-05],
#   'predicted_label': 1},
#  {'score': [0.002014454919844866,
#    0.9828944206237793,
#    0.014566120691597462,
#    0.0005250080721452832],
#   'predicted_label': 1},
#  {'score': [0.0028516780585050583,
#    0.032750993967056274,
#    0.0015308746369555593,
#    0.9628664255142212],
#   'predicted_label': 3},
#  {'score': [0.0988430455327034,
#    0.8654569983482361,
#    0.03567375987768173,
#    2.6197056286036968e-05],
#   'predicted_label': 1},
#  {'score': [0.0003138291649520397,
#    0.9940164685249329,
#    0.0030306277330964804,
#    0.0026390845887362957],
#   'predicted_label': 1},
#  {'score': [0.02755659632384777,
#    0.4728212356567383,
#    0.4993606209754944,
#    0.0002615411940496415],
#   'predicted_label': 2},
#  {'score': [0.44764837622642517,
#    0.07063264399766922,
#    0.48171892762184143,
#    1.4320209018592323e-08],
#   'predicted_label': 2},
#  {'score': [0.08077669888734818,
#    0.8935033082962036,
#    0.024788688868284225,
#    0.0009313389891758561],
#   'predicted_label': 1},
#  {'score': [0.8363665342330933,
#    0.0330011248588562,
#    0.13062216341495514,
#    1.0130362170457374e-05],
#   'predicted_label': 0},
#  {'score': [0.1273581087589264,
#    0.7727388739585876,
#    0.09905509650707245,
#    0.0008478782256133854],
#   'predicted_label': 1},
#  {'score': [0.8579775094985962,
#    0.07441715896129608,
#    0.06589685380458832,
#    0.001708450261503458],
#   'predicted_label': 0},
#  {'score': [0.006558554247021675,
#    0.05092746019363403,
#    0.0011422553798183799,
#    0.941371738910675],
#   'predicted_label': 3},
#  {'score': [0.5338733196258545,
#    0.016734549775719643,
#    0.44938814640045166,
#    3.963217295677168e-06],
#   'predicted_label': 0},
#  {'score': [0.00417859572917223,
#    0.957379937171936,
#    0.03514118120074272,
#    0.0033002495765686035],
#   'predicted_label': 1},
#  {'score': [0.9182921051979065,
#    0.023624559864401817,
#    0.04160219058394432,
#    0.016481170430779457],
#   'predicted_label': 0},
#  {'score': [0.22130921483039856,
#    0.033383820205926895,
#    0.7452898621559143,
#    1.710994911263697e-05],
#   'predicted_label': 2},
#  {'score': [0.9382134675979614,
#    0.019474953413009644,
#    0.041387904435396194,
#    0.0009237051708623767],
#   'predicted_label': 0},
#  {'score': [0.9691305160522461,
#    0.021113622933626175,
#    0.009722677990794182,
#    3.317575465189293e-05],
#   'predicted_label': 0},
#  {'score': [0.009973948821425438,
#    0.037815652787685394,
#    0.9521493911743164,
#    6.091866816859692e-05],
#   'predicted_label': 2},
#  {'score': [0.009270671755075455,
#    0.975636899471283,
#    0.014910328201949596,
#    0.00018207385437563062],
#   'predicted_label': 1},
#  {'score': [0.007632776629179716,
#    0.7696685194969177,
#    0.22121639549732208,
#    0.0014823245583102107],
#   'predicted_label': 1},
#  {'score': [0.0018583731725811958,
#    0.9867331385612488,
#    0.010187479667365551,
#    0.001220972859300673],
#   'predicted_label': 1},
#  {'score': [0.5692651867866516,
#    0.12417145818471909,
#    0.12535329163074493,
#    0.18121005594730377],
#   'predicted_label': 0},
#  {'score': [0.020869217813014984,
#    0.09650734812021255,
#    0.8826215267181396,
#    1.847912358243775e-06],
#   'predicted_label': 2},
#  {'score': [0.06526552885770798,
#    0.021260268986225128,
#    0.9134741425514221,
#    1.003326133286464e-07],
#   'predicted_label': 2},
#  {'score': [0.10637983679771423,
#    0.14361149072647095,
#    0.7500086426734924,
#    2.6381761220051203e-09],
#   'predicted_label': 2},
#  {'score': [0.26940444111824036,
#    0.1735963672399521,
#    0.5569979548454285,
#    1.2139354339524289e-06],
#   'predicted_label': 2},
#  {'score': [0.5291100740432739,
#    0.20020946860313416,
#    0.2706770598888397,
#    3.3865410387079464e-06],
#   'predicted_label': 0},
#  {'score': [0.5004978775978088,
#    0.022000253200531006,
#    0.47750189900398254,
#    1.000000013351432e-10],
#   'predicted_label': 0},
#  {'score': [0.13148942589759827,
#    0.6819373369216919,
#    0.1861996054649353,
#    0.00037363357841968536],
#   'predicted_label': 1},
#  {'score': [0.3958454132080078,
#    0.19008126854896545,
#    0.4140598177909851,
#    1.3500288332579657e-05],
#   'predicted_label': 2},
#  {'score': [0.8850657343864441,
#    0.04813189059495926,
#    0.0629882663488388,
#    0.0038141331169754267],
#   'predicted_label': 0},
#  {'score': [0.7694645524024963,
#    0.12997736036777496,
#    0.07234867662191391,
#    0.028209421783685684],
#   'predicted_label': 0},
#  {'score': [0.6565217971801758,
#    0.20590654015541077,
#    0.1374637335538864,
#    0.00010789841326186433],
#   'predicted_label': 0},
#  {'score': [0.022278709337115288,
#    0.35373324155807495,
#    0.623576819896698,
#    0.00041124640847556293],
#   'predicted_label': 2},
#  {'score': [0.5032266974449158,
#    0.06250275671482086,
#    0.43423986434936523,
#    3.073922198382206e-05],
#   'predicted_label': 0},
#  {'score': [0.3737483024597168,
#    0.1858503520488739,
#    0.44039151072502136,
#    9.876764124783222e-06],
#   'predicted_label': 2},
#  {'score': [0.007460391148924828,
#    0.14505380392074585,
#    0.8474856019020081,
#    2.518627297831699e-07],
#   'predicted_label': 2},
#  {'score': [0.005521257407963276,
#    0.06136556342244148,
#    0.0019565459806472063,
#    0.9311566352844238],
#   'predicted_label': 3},
#  {'score': [0.006008445750921965,
#    0.040050532668828964,
#    0.0008881003013812006,
#    0.9530529379844666],
#   'predicted_label': 3},
#  {'score': [0.4919050931930542,
#    0.20959927141666412,
#    0.29846853017807007,
#    2.7073037927038968e-05],
#   'predicted_label': 0},
#  {'score': [0.06107505410909653,
#    0.7770244479179382,
#    0.16178055107593536,
#    0.00011993746738880873],
#   'predicted_label': 1},
#  {'score': [0.0020993477664887905,
#    0.0083328727632761,
#    0.9895644783973694,
#    3.27974612446269e-06],
#   'predicted_label': 2},
#  {'score': [0.027531499043107033,
#    0.04470457509160042,
#    0.0008777937619015574,
#    0.9268861413002014],
#   'predicted_label': 3},
#  {'score': [0.3116283118724823,
#    0.5954752564430237,
#    0.08314491808414459,
#    0.009751466102898121],
#   'predicted_label': 1},
#  {'score': [0.32840725779533386,
#    0.1943867951631546,
#    0.4772058427333832,
#    1.0822916607367006e-07],
#   'predicted_label': 2},
#  {'score': [0.17882147431373596,
#    0.10719791799783707,
#    0.7139793634414673,
#    1.1896108844666742e-06],
#   'predicted_label': 2},
#  {'score': [0.09575345367193222,
#    0.18591657280921936,
#    0.7183300256729126,
#    3.305469231662528e-09],
#   'predicted_label': 2},
#  {'score': [0.6977052092552185,
#    0.035952482372522354,
#    0.26633691787719727,
#    5.357457666832488e-06],
#   'predicted_label': 0},
#  {'score': [0.009598628617823124,
#    0.03878596052527428,
#    0.0009038138668984175,
#    0.9507116079330444],
#   'predicted_label': 3},
#  ...]

# %%
result = linear_regressor.predict(X_test)
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
result['predictions'][1187]
y_pred = [np.argmax(x['score']) for x in result['predictions'] ]

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.847953216374269

# %%
# delete endpoints
linear_regressor.delete_endpoint()

# %% [markdown]
# # Load the already trained Model

# %%
import os
import mxnet as mx
import boto3

bucket = "sagemaker-us-east-1-410677554255"
key = "linear-learner/output/linear-learner-2022-11-10-15-56-58-055/output/"
boto3.resource('s3').Bucket(bucket).download_file(key, 'model.tar.gz')

os.system('tar -zxvf model.tar.gz')

# Linear learner model is itself a zip file, containing a mxnet model and other metadata.
# First unzip the model.
os.system('unzip model_algo-1') 

# Load the mxnet module
mod = mx.module.Module.load("mx-mod", 0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6803/395678752.py in <cell line: 2>()
#       1 import os
# ----> 2 import mxnet as mx
#       3 import boto3
#       4
#       5 bucket = "sagemaker-us-east-1-410677554255"
#
# ModuleNotFoundError: No module named 'mxnet'
